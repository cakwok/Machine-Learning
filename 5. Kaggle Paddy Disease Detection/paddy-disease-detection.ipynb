# %%
'''
CS6140 Final Project - Paddy Disease Detection – Can technology help relieving Food Crisis 2022?
Aug 1, 2022
Wing Man, Kwok

'''
import torch
from torch import nn, optim
import torch.nn.functional as F
from torchvision import models, datasets, transforms
from sklearn.model_selection import train_test_split
from PIL import Image        #convert Images to tensor
from torch.utils.data import Dataset, DataLoader
import cv2
import torchvision.transforms as T
from PIL import Image
from torchvision import transforms

import sys
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time

# %%
def get_hyperparameters():
    
    batch_size = 128
    learning_rate = 1e-3
    n_epochs = 5
    log_interval = 10
    momentum = 0.5
    
    return batch_size, learning_rate, n_epochs, log_interval, momentum

# %%
def check_processor():
    
    if torch.cuda.is_available():
        device = 'cuda'
        print('Using cuda\n')
    else:
        device = 'cpu'
        print('Using cpu\n')
        
    return device

# %%
def split_train_test_dataset(training_csv):
       
    train_paths, val_paths, train_labels, val_labels = train_test_split(training_csv["image_id"], training_csv["label"], test_size=0.2, random_state=42)
    
    return train_paths, val_paths, train_labels, val_labels

# %%
class PaddyDataset(Dataset):
    
    def __init__(self, dataframe, label2id, root_dir, is_train, transform=None):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform
        self.is_train = is_train
        self.label2id = label2id
        
    def __len__(self):
        return len(self.dataframe)
        
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        img_name = os.path.join(self.root_dir,self.dataframe.iloc[idx, 1],
                                self.dataframe.iloc[idx, 0])
        
        image1 = cv2.imread(img_name)
        image = Image.fromarray(image1)
        
        if self.is_train:
            labelKey = self.dataframe.iloc[idx, 1]
            label = torch.tensor(int(self.label2id[labelKey]))  
        else:
            label =torch.tensor(1)

        if self.transform:
            image = self.transform(image)
        
        return image,label, img_name

# %%
def get_label2id(training_csv):
    
    labelArr = training_csv['label'].unique()
    label2id = {}
    id2label = {}
    index = 0
    
    for  class_name in labelArr:
        label2id[class_name] = str(index)
        id2label[str(index)] = class_name
        index=index +1
  
    return label2id, id2label

# %%
def EDA(paddy_dataset, images, labels, training_csv):
    
    print("EDA:", "\n")
          
    print("Training Dataset size:", len(paddy_dataset), "\n")
    print("Label Distribution:\n")
    print(paddy_dataset['label'].value_counts(), "\n")
    
    print("Image size (channel, height, width):", images[0].shape, "\n")
    #print("Visualization of batch #1:")
    #print("-------------------------\n")
    #print("True Labels:\n", labels, len(labels), "\n")

# %%
def plot(images, labels, id2label, img_name):
    
    plt.subplots(figsize=(15, 15))
    
    for i in range(5):
        plt.subplot(1, 5, i+1)
        plt.tight_layout()
        plt.axis("off"); plt.xticks([]) ; plt.yticks([]) 
        plt.title("Ground Truth: {}".format(id2label[str(labels[i])]))
        
        images_rgb = images[i].squeeze()
        images_rgb = (np.transpose(images_rgb, (0, 2, 1)).T).detach().numpy()
        plt.imshow(cv2.cvtColor(images_rgb, cv2.COLOR_BGR2RGB))
        
        print(img_name[i])
        
    plt.show()

# %%
def train_model(n_epochs, model, train_loader, optimizer, log_interval, device):
    
    model.train()
    
    start_time = time.time()
    train_losses = []
    train_counter = []
    criterion = nn.CrossEntropyLoss()
    
    for batch_idx, (data, target, _) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()                           
        output = model(data)
        loss = criterion(output, target)
        #loss = F.nll_loss(output, target)               
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(n_epochs, batch_idx * len(data), len(train_loader.dataset), 100. * batch_idx / len(train_loader), loss.item()))
            train_losses.append(loss.item())
            train_counter.append((batch_idx*64) + ((n_epochs-1)*len(train_loader.dataset)))
            '''
            torch.save(model.state_dict(), './model.pth') 
            torch.save(optimizer.state_dict(), './optimizer.pth')
            '''
    total_time = time.time() - start_time
    print("Total running time:", total_time)

# %%
def val_model(model, val_loader, device):
    model.eval()
    
    test_loss = 0
    correct = 0
    model_output = []
    test_losses = []
    files = []
    
    criterion = nn.CrossEntropyLoss()
    
    with torch.no_grad():                   #no_grad means no gradient magnitude
        for data, target, file_name in val_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            #test_loss += F.nll_loss(output, target, size_average=False).item()
            test_loss += criterion(output, target)
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum()
            model_output.append(output)
            files.append(file_name)
            
    test_loss /= len(val_loader.dataset)
    test_losses.append(test_loss)
    accuracy = 100. * correct / len(val_loader.dataset)
    
    print('\nTest set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(test_loss, correct, len(val_loader.dataset), 100. * correct / len(val_loader.dataset)))

    return model_output[0], files, accuracy.item()

# %%
def get_resnet_by_batch_size(model, train_dataset, valid_dataset, batch_size, device):
    
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, num_workers=2, shuffle=True)
    val_dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size = batch_size, num_workers=2)
    
    model.fc =  nn.Sequential(nn.Dropout(0.1),nn.Linear(512, 10))
    model = model.to(device)
    
    return train_dataloader, val_dataloader, model

# %%
def main(argv):

    torch.cuda.empty_cache()
    
    # -------- Prepare dataset
    start_time = time.time()
    
    torch.manual_seed(42)  
    torch.backends.cudnn.enabled = False
    
    batch_size, learning_rate, n_epochs, log_interval, momentum  = get_hyperparameters()

    training_csv = pd.read_csv("../input/paddy-doctor/train.csv")
    train, valid = train_test_split(training_csv, test_size=0.05,random_state=0)
    print("Training Dataset size:", len(train), "Validation Dataset Size:", len(valid), "\n")
    
    label2id, id2label = get_label2id(training_csv)
    print("id2label", id2label, "\n")
    print("label2id", label2id, "\n")

    transform_dataset = transforms.Compose([transforms.ToTensor(), transforms.Resize((224,224))])
    
    train_dataset = PaddyDataset(train, label2id, root_dir='../input/paddy-doctor/train_images', is_train=True, transform=transform_dataset)
    valid_dataset = PaddyDataset(valid, label2id, root_dir='../input/paddy-doctor/train_images', is_train=True, transform=transform_dataset)
    
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, num_workers=2, shuffle=True)
    val_dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size = batch_size, num_workers=2)
    
    images, labels, img_name = next(iter(train_dataloader))
    print("Images of first training batch")
    plot(images, labels.tolist(), id2label, img_name)
    
    EDA(train, images, labels, training_csv)

    device = check_processor()
    
    # --------- Define resnet34 model
    resnet34 = models.resnet34(pretrained=True)
    resnet34.fc =  nn.Sequential(nn.Dropout(0.1),nn.Linear(512, 10))
    resnet34 = resnet34.to(device)
    
    optimizer_resnet34 = optim.SGD(resnet34.parameters(), lr=learning_rate, momentum=momentum)
    
    # --------- Define resnet18 model
    resnet18 = models.resnet18(pretrained=True)
    resnet18.fc =  nn.Sequential(nn.Dropout(0.1),nn.Linear(512, 10))
    resnet18 = resnet18.to(device)
    
    optimizer_resnet18 = optim.SGD(resnet18.parameters(), lr=learning_rate, momentum=momentum)
    
    # ---------- load previous training weights
    
    '''
    network_state_dict = torch.load('../input/paddy-disease-detection/model.pth', map_location = device)
    resnet34.load_state_dict(network_state_dict)
    
    optimizer_state_dict = torch.load('../input/paddy-disease-detection/optimizer.pth', map_location = device)
    optimizer.load_state_dict(optimizer_state_dict)
    '''
    
    # ------- Train Resnet34 as baseline for comparison
    
    n_epochs = 50
    
    accuracy_resnet34 = []
    
    for epoch in range(1, n_epochs + 1): 
        print("Training Resnet34")
        train_model(epoch, resnet34, train_dataloader, optimizer_resnet34, log_interval, device)
        pred, filenames, accuracy = val_model(resnet34, val_dataloader, device)
        accuracy_resnet34.append(accuracy)
               
    print("accuracy_resnet34", accuracy_resnet34)
        
    # ------- Visualize reset34 baseline prediction
    test_samples = enumerate(val_dataloader)
    batch_idx, (test_images, test_targets, _) = next(test_samples)
    print("test_targets")
    print(test_targets)
    print("test_images shape", test_images.shape)
    
    pred, filenames, accuracy = val_model(resnet34, val_dataloader, device)
    
    transform = T.ToPILImage()
    
    plt.subplots(figsize=(15, 15))
    
    for i in range(10):
        plt.subplot(3, 5, i+1)
        plt.tight_layout()
        plt.axis("off"); plt.xticks([]) ; plt.yticks([]) 
        
        prediction = np.argmax(pred[i].cpu()).item()
        plt.title("Prediction: {}".format(id2label[str(prediction)]))
        
        plt.imshow(cv2.cvtColor(cv2.imread(filenames[0][i]), cv2.COLOR_BGR2RGB))
      
        print(filenames[0][i])
        
    plt.show()
    
    # ----- Train Resnet18 and compare Resnet34 and Reset18
    
    accuracy_resnet18 = []
    
    for epoch in range(1, n_epochs + 1): 
        print("Training Resnet18")
        train_model(epoch, resnet18, train_dataloader, optimizer_resnet18, log_interval, device)
        pred, filenames, accuracy = val_model(resnet18, val_dataloader, device)
        accuracy_resnet18.append(accuracy)
 
    print("accuracy_resnet18", accuracy_resnet18)

    epoch = np.linspace(1,len(accuracy_resnet34),len(accuracy_resnet34));
    
    plt.title("Compare Performance of Resnet34 and Reset18"); plt.xlabel("Epoch"); plt.ylabel("Prediction Accuracy(%)")
    plt.plot(epoch, accuracy_resnet34, color = 'blue' )
    plt.plot(epoch, accuracy_resnet18, color = 'red' )
    plt.legend(['Resnet34', 'Resnet18'], loc='upper right')
    plt.show()
    
    # ------ Compare Batch Size
    # -------------------------- Get model by batch size 256
    
    batch_size = 256
    accuracy_resnet34_batch_256 = []
    
    resnet34_batch_256 = models.resnet34(pretrained=True)
    
    train_dataloader, val_dataloader, resnet34_batch_256 = get_resnet_by_batch_size(resnet34_batch_256, train_dataset, valid_dataset, batch_size, device)

    optimizer_resnet34_batch_256 = optim.SGD(resnet34_batch_256.parameters(), lr=learning_rate, momentum=momentum)
    
    for epoch in range(1, n_epochs + 1): 
        print("Training Resnet34, batch size", batch_size)
        train_model(epoch, resnet34_batch_256, train_dataloader, optimizer_resnet34_batch_256, log_interval, device)
        pred, filenames, accuracy = val_model(resnet34_batch_256, val_dataloader, device)
        accuracy_resnet34_batch_256.append(accuracy)
               
    print("accuracy_resnet34_batch_256", accuracy_resnet34_batch_256, "\n")
    
     # -------------------------- Get model by batch size 512
        
    batch_size = 384   
    accuracy_resnet34_batch_384 = []
    
    resnet34_batch_384 = models.resnet34(pretrained=True)
    
    train_dataloader, val_dataloader, resnet34_batch_384 = get_resnet_by_batch_size(resnet34_batch_384, train_dataset, valid_dataset, batch_size, device)

    optimizer_resnet34_batch_384 = optim.SGD(resnet34_batch_384.parameters(), lr=learning_rate, momentum=momentum)
    
    for epoch in range(1, n_epochs + 1): 
        print("Training Resnet34, batch size", batch_size)
        train_model(epoch, resnet34_batch_384, train_dataloader, optimizer_resnet34_batch_384, log_interval, device)
        pred, filenames, accuracy = val_model(resnet34_batch_384, val_dataloader, device)
        accuracy_resnet34_batch_384.append(accuracy)
               
    print("accuracy_resnet34_batch_384", accuracy_resnet34_batch_384)
    
    epoch = np.linspace(1,len(accuracy_resnet34_batch_256),len(accuracy_resnet34_batch_256));
    
    plt.title("Compare Performance of Batch Size"); plt.xlabel("Epoch"); plt.ylabel("Prediction Accuracy(%)")
    plt.plot(epoch, accuracy_resnet34, color = 'blue' )
    plt.plot(epoch, accuracy_resnet34_batch_256, color = 'red' )
    plt.plot(epoch, accuracy_resnet34_batch_384, color = 'green' )
    plt.legend(['Batch Size = 128', 'Batch Size = 256', 'Batch Size = 384'], loc='upper right')
    plt.show()
    
    # ----- Compute total time
    total_time = time.time() - start_time
    print("Total running time:", total_time)
                  
    return

if __name__ == "__main__":
    main(sys.argv)


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Training Dataset size: 9886 Validation Dataset Size: 521
#
# id2label {'0': 'bacterial_leaf_blight', '1': 'bacterial_leaf_streak', '2': 'bacterial_panicle_blight', '3': 'blast', '4': 'brown_spot', '5': 'dead_heart', '6': 'downy_mildew', '7': 'hispa', '8': 'normal', '9': 'tungro'}
#
# label2id {'bacterial_leaf_blight': '0', 'bacterial_leaf_streak': '1', 'bacterial_panicle_blight': '2', 'blast': '3', 'brown_spot': '4', 'dead_heart': '5', 'downy_mildew': '6', 'hispa': '7', 'normal': '8', 'tungro': '9'}
#
# Images of first training batch
# ../input/paddy-doctor/train_images/normal/100664.jpg
# ../input/paddy-doctor/train_images/normal/109781.jpg
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matricesor `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at  /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:2314.)
#   if sys.path[0] == "":
# ../input/paddy-doctor/train_images/dead_heart/101724.jpg
# ../input/paddy-doctor/train_images/hispa/106414.jpg
# ../input/paddy-doctor/train_images/bacterial_leaf_streak/108603.jpg
# EDA:
#
# Training Dataset size: 9886
#
# Label Distribution:
#
# normal                      1683
# blast                       1651
# hispa                       1498
# dead_heart                  1370
# tungro                      1036
# brown_spot                   913
# downy_mildew                 586
# bacterial_leaf_blight        463
# bacterial_leaf_streak        363
# bacterial_panicle_blight     323
# Name: label, dtype: int64
#
# Image size (channel, height, width): torch.Size([3, 224, 224])
#
# Using cuda
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# Training Resnet34
# Train Epoch: 1 [0/9886 (0%)]	Loss: 2.880819
# Train Epoch: 1 [1280/9886 (13%)]	Loss: 2.297585
# Train Epoch: 1 [2560/9886 (26%)]	Loss: 2.174744
# Train Epoch: 1 [3840/9886 (38%)]	Loss: 2.167447
# Train Epoch: 1 [5120/9886 (51%)]	Loss: 2.028553
# Train Epoch: 1 [6400/9886 (64%)]	Loss: 2.008653
# Train Epoch: 1 [7680/9886 (77%)]	Loss: 1.963067
# Train Epoch: 1 [8960/9886 (90%)]	Loss: 2.073795
# Total running time: 136.84332251548767
#
# Test set: Avg. loss: 0.0186, Accuracy: 196/521 (38%)
#
# Training Resnet34
# Train Epoch: 2 [0/9886 (0%)]	Loss: 1.914975
# Train Epoch: 2 [1280/9886 (13%)]	Loss: 1.844753
# Train Epoch: 2 [2560/9886 (26%)]	Loss: 1.807642
# Train Epoch: 2 [3840/9886 (38%)]	Loss: 1.853411
# Train Epoch: 2 [5120/9886 (51%)]	Loss: 1.814762
# Train Epoch: 2 [6400/9886 (64%)]	Loss: 1.811773
# Train Epoch: 2 [7680/9886 (77%)]	Loss: 1.649709
# Train Epoch: 2 [8960/9886 (90%)]	Loss: 1.765423
# Total running time: 125.39438772201538
#
# Test set: Avg. loss: 0.0162, Accuracy: 252/521 (48%)
#
# Training Resnet34
# Train Epoch: 3 [0/9886 (0%)]	Loss: 1.556188
# Train Epoch: 3 [1280/9886 (13%)]	Loss: 1.583175
# Train Epoch: 3 [2560/9886 (26%)]	Loss: 1.564327
# Train Epoch: 3 [3840/9886 (38%)]	Loss: 1.601678
# Train Epoch: 3 [5120/9886 (51%)]	Loss: 1.712763
# Train Epoch: 3 [6400/9886 (64%)]	Loss: 1.513709
# Train Epoch: 3 [7680/9886 (77%)]	Loss: 1.555956
# Train Epoch: 3 [8960/9886 (90%)]	Loss: 1.427000
# Total running time: 125.26044178009033
#
# Test set: Avg. loss: 0.0140, Accuracy: 286/521 (55%)
#
# Training Resnet34
# Train Epoch: 4 [0/9886 (0%)]	Loss: 1.428456
# Train Epoch: 4 [1280/9886 (13%)]	Loss: 1.549926
# Train Epoch: 4 [2560/9886 (26%)]	Loss: 1.337932
# Train Epoch: 4 [3840/9886 (38%)]	Loss: 1.303683
# Train Epoch: 4 [5120/9886 (51%)]	Loss: 1.190336
# Train Epoch: 4 [6400/9886 (64%)]	Loss: 1.241856
# Train Epoch: 4 [7680/9886 (77%)]	Loss: 1.180501
# Train Epoch: 4 [8960/9886 (90%)]	Loss: 1.207319
# Total running time: 125.63980770111084
#
# Test set: Avg. loss: 0.0124, Accuracy: 312/521 (60%)
#
# Training Resnet34
# Train Epoch: 5 [0/9886 (0%)]	Loss: 1.207613
# Train Epoch: 5 [1280/9886 (13%)]	Loss: 1.243199
# Train Epoch: 5 [2560/9886 (26%)]	Loss: 1.146727
# Train Epoch: 5 [3840/9886 (38%)]	Loss: 1.026093
# Train Epoch: 5 [5120/9886 (51%)]	Loss: 1.095612
# Train Epoch: 5 [6400/9886 (64%)]	Loss: 1.108772
# Train Epoch: 5 [7680/9886 (77%)]	Loss: 0.932416
# Train Epoch: 5 [8960/9886 (90%)]	Loss: 1.058014
# Total running time: 124.95851469039917
#
# Test set: Avg. loss: 0.0110, Accuracy: 333/521 (64%)
#
# Training Resnet34
# Train Epoch: 6 [0/9886 (0%)]	Loss: 1.047224
# Train Epoch: 6 [1280/9886 (13%)]	Loss: 1.094197
# Train Epoch: 6 [2560/9886 (26%)]	Loss: 0.978629
# Train Epoch: 6 [3840/9886 (38%)]	Loss: 1.051836
# Train Epoch: 6 [5120/9886 (51%)]	Loss: 0.943882
# Train Epoch: 6 [6400/9886 (64%)]	Loss: 0.887627
# Train Epoch: 6 [7680/9886 (77%)]	Loss: 0.918324
# Train Epoch: 6 [8960/9886 (90%)]	Loss: 1.009855
# Total running time: 124.39514493942261
#
# Test set: Avg. loss: 0.0101, Accuracy: 347/521 (67%)
#
# Training Resnet34
# Train Epoch: 7 [0/9886 (0%)]	Loss: 0.928692
# Train Epoch: 7 [1280/9886 (13%)]	Loss: 0.827479
# Train Epoch: 7 [2560/9886 (26%)]	Loss: 0.863718
# Train Epoch: 7 [3840/9886 (38%)]	Loss: 0.907071
# Train Epoch: 7 [5120/9886 (51%)]	Loss: 0.690885
# Train Epoch: 7 [6400/9886 (64%)]	Loss: 0.898177
# Train Epoch: 7 [7680/9886 (77%)]	Loss: 0.868573
# Train Epoch: 7 [8960/9886 (90%)]	Loss: 0.694024
# Total running time: 125.15668487548828
#
# Test set: Avg. loss: 0.0093, Accuracy: 365/521 (70%)
#
# Training Resnet34
# Train Epoch: 8 [0/9886 (0%)]	Loss: 0.793302
# Train Epoch: 8 [1280/9886 (13%)]	Loss: 0.749303
# Train Epoch: 8 [2560/9886 (26%)]	Loss: 0.903336
# Train Epoch: 8 [3840/9886 (38%)]	Loss: 0.834972
# Train Epoch: 8 [5120/9886 (51%)]	Loss: 0.724791
# Train Epoch: 8 [6400/9886 (64%)]	Loss: 0.844885
# Train Epoch: 8 [7680/9886 (77%)]	Loss: 0.737550
# Train Epoch: 8 [8960/9886 (90%)]	Loss: 0.723247
# Total running time: 124.81249499320984
#
# Test set: Avg. loss: 0.0086, Accuracy: 382/521 (73%)
#
# Training Resnet34
# Train Epoch: 9 [0/9886 (0%)]	Loss: 0.579574
# Train Epoch: 9 [1280/9886 (13%)]	Loss: 0.655598
# Train Epoch: 9 [2560/9886 (26%)]	Loss: 0.752860
# Train Epoch: 9 [3840/9886 (38%)]	Loss: 0.571534
# Train Epoch: 9 [5120/9886 (51%)]	Loss: 0.605228
# Train Epoch: 9 [6400/9886 (64%)]	Loss: 0.842831
# Train Epoch: 9 [7680/9886 (77%)]	Loss: 0.690853
# Train Epoch: 9 [8960/9886 (90%)]	Loss: 0.688913
# Total running time: 124.68921709060669
#
# Test set: Avg. loss: 0.0080, Accuracy: 393/521 (75%)
#
# Training Resnet34
# Train Epoch: 10 [0/9886 (0%)]	Loss: 0.699411
# Train Epoch: 10 [1280/9886 (13%)]	Loss: 0.584808
# Train Epoch: 10 [2560/9886 (26%)]	Loss: 0.591538
# Train Epoch: 10 [3840/9886 (38%)]	Loss: 0.580703
# Train Epoch: 10 [5120/9886 (51%)]	Loss: 0.504949
# Train Epoch: 10 [6400/9886 (64%)]	Loss: 0.534754
# Train Epoch: 10 [7680/9886 (77%)]	Loss: 0.710438
# Train Epoch: 10 [8960/9886 (90%)]	Loss: 0.603579
# Total running time: 125.73838520050049
#
# Test set: Avg. loss: 0.0075, Accuracy: 402/521 (77%)
#
# Training Resnet34
# Train Epoch: 11 [0/9886 (0%)]	Loss: 0.520121
# Train Epoch: 11 [1280/9886 (13%)]	Loss: 0.574644
# Train Epoch: 11 [2560/9886 (26%)]	Loss: 0.526015
# Train Epoch: 11 [3840/9886 (38%)]	Loss: 0.620057
# Train Epoch: 11 [5120/9886 (51%)]	Loss: 0.511704
# Train Epoch: 11 [6400/9886 (64%)]	Loss: 0.571650
# Train Epoch: 11 [7680/9886 (77%)]	Loss: 0.474648
# Train Epoch: 11 [8960/9886 (90%)]	Loss: 0.548023
# Total running time: 124.33293390274048
#
# Test set: Avg. loss: 0.0071, Accuracy: 409/521 (79%)
#
# Training Resnet34
# Train Epoch: 12 [0/9886 (0%)]	Loss: 0.512748
# Train Epoch: 12 [1280/9886 (13%)]	Loss: 0.443254
# Train Epoch: 12 [2560/9886 (26%)]	Loss: 0.503437
# Train Epoch: 12 [3840/9886 (38%)]	Loss: 0.536483
# Train Epoch: 12 [5120/9886 (51%)]	Loss: 0.475165
# Train Epoch: 12 [6400/9886 (64%)]	Loss: 0.506657
# Train Epoch: 12 [7680/9886 (77%)]	Loss: 0.426858
# Train Epoch: 12 [8960/9886 (90%)]	Loss: 0.442761
# Total running time: 125.67514681816101
#
# Test set: Avg. loss: 0.0067, Accuracy: 420/521 (81%)
#
# Training Resnet34
# Train Epoch: 13 [0/9886 (0%)]	Loss: 0.483918
# Train Epoch: 13 [1280/9886 (13%)]	Loss: 0.429068
# Train Epoch: 13 [2560/9886 (26%)]	Loss: 0.414923
# Train Epoch: 13 [3840/9886 (38%)]	Loss: 0.402050
# Train Epoch: 13 [5120/9886 (51%)]	Loss: 0.487332
# Train Epoch: 13 [6400/9886 (64%)]	Loss: 0.363226
# Train Epoch: 13 [7680/9886 (77%)]	Loss: 0.420497
# Train Epoch: 13 [8960/9886 (90%)]	Loss: 0.407651
# Total running time: 125.31787633895874
#
# Test set: Avg. loss: 0.0063, Accuracy: 429/521 (82%)
#
# Training Resnet34
# Train Epoch: 14 [0/9886 (0%)]	Loss: 0.455853
# Train Epoch: 14 [1280/9886 (13%)]	Loss: 0.464464
# Train Epoch: 14 [2560/9886 (26%)]	Loss: 0.317494
# Train Epoch: 14 [3840/9886 (38%)]	Loss: 0.279858
# Train Epoch: 14 [5120/9886 (51%)]	Loss: 0.306363
# Train Epoch: 14 [6400/9886 (64%)]	Loss: 0.385890
# Train Epoch: 14 [7680/9886 (77%)]	Loss: 0.365578
# Train Epoch: 14 [8960/9886 (90%)]	Loss: 0.292092
# Total running time: 124.86314988136292
#
# Test set: Avg. loss: 0.0060, Accuracy: 430/521 (83%)
#
# Training Resnet34
# Train Epoch: 15 [0/9886 (0%)]	Loss: 0.350016
# Train Epoch: 15 [1280/9886 (13%)]	Loss: 0.305572
# Train Epoch: 15 [2560/9886 (26%)]	Loss: 0.362118
# Train Epoch: 15 [3840/9886 (38%)]	Loss: 0.265420
# Train Epoch: 15 [5120/9886 (51%)]	Loss: 0.322448
# Train Epoch: 15 [6400/9886 (64%)]	Loss: 0.309431
# Train Epoch: 15 [7680/9886 (77%)]	Loss: 0.295706
# Train Epoch: 15 [8960/9886 (90%)]	Loss: 0.323673
# Total running time: 124.04361581802368
#
# Test set: Avg. loss: 0.0057, Accuracy: 441/521 (85%)
#
# Training Resnet34
# Train Epoch: 16 [0/9886 (0%)]	Loss: 0.298965
# Train Epoch: 16 [1280/9886 (13%)]	Loss: 0.260361
# Train Epoch: 16 [2560/9886 (26%)]	Loss: 0.228047
# Train Epoch: 16 [3840/9886 (38%)]	Loss: 0.311428
# Train Epoch: 16 [5120/9886 (51%)]	Loss: 0.281704
# Train Epoch: 16 [6400/9886 (64%)]	Loss: 0.205464
# Train Epoch: 16 [7680/9886 (77%)]	Loss: 0.268272
# Train Epoch: 16 [8960/9886 (90%)]	Loss: 0.310989
# Total running time: 123.97362661361694
#
# Test set: Avg. loss: 0.0055, Accuracy: 441/521 (85%)
#
# Training Resnet34
# Train Epoch: 17 [0/9886 (0%)]	Loss: 0.341325
# Train Epoch: 17 [1280/9886 (13%)]	Loss: 0.251875
# Train Epoch: 17 [2560/9886 (26%)]	Loss: 0.176759
# Train Epoch: 17 [3840/9886 (38%)]	Loss: 0.230715
# Train Epoch: 17 [5120/9886 (51%)]	Loss: 0.267294
# Train Epoch: 17 [6400/9886 (64%)]	Loss: 0.185360
# Train Epoch: 17 [7680/9886 (77%)]	Loss: 0.229475
# Train Epoch: 17 [8960/9886 (90%)]	Loss: 0.248671
# Total running time: 126.21796035766602
#
# Test set: Avg. loss: 0.0053, Accuracy: 447/521 (86%)
#
# Training Resnet34
# Train Epoch: 18 [0/9886 (0%)]	Loss: 0.263437
# Train Epoch: 18 [1280/9886 (13%)]	Loss: 0.214904
# Train Epoch: 18 [2560/9886 (26%)]	Loss: 0.210036
# Train Epoch: 18 [3840/9886 (38%)]	Loss: 0.213905
# Train Epoch: 18 [5120/9886 (51%)]	Loss: 0.237515
# Train Epoch: 18 [6400/9886 (64%)]	Loss: 0.231295
# Train Epoch: 18 [7680/9886 (77%)]	Loss: 0.218873
# Train Epoch: 18 [8960/9886 (90%)]	Loss: 0.243503
# Total running time: 126.69834780693054
#
# Test set: Avg. loss: 0.0051, Accuracy: 449/521 (86%)
#
# Training Resnet34
# Train Epoch: 19 [0/9886 (0%)]	Loss: 0.208525
# Train Epoch: 19 [1280/9886 (13%)]	Loss: 0.180982
# Train Epoch: 19 [2560/9886 (26%)]	Loss: 0.229538
# Train Epoch: 19 [3840/9886 (38%)]	Loss: 0.187300
# Train Epoch: 19 [5120/9886 (51%)]	Loss: 0.190659
# Train Epoch: 19 [6400/9886 (64%)]	Loss: 0.233915
# Train Epoch: 19 [7680/9886 (77%)]	Loss: 0.199456
# Train Epoch: 19 [8960/9886 (90%)]	Loss: 0.152062
# Total running time: 127.16212701797485
#
# Test set: Avg. loss: 0.0050, Accuracy: 452/521 (87%)
#
# Training Resnet34
# Train Epoch: 20 [0/9886 (0%)]	Loss: 0.164736
# Train Epoch: 20 [1280/9886 (13%)]	Loss: 0.199504
# Train Epoch: 20 [2560/9886 (26%)]	Loss: 0.196472
# Train Epoch: 20 [3840/9886 (38%)]	Loss: 0.187063
# Train Epoch: 20 [5120/9886 (51%)]	Loss: 0.119144
# Train Epoch: 20 [6400/9886 (64%)]	Loss: 0.140457
# Train Epoch: 20 [7680/9886 (77%)]	Loss: 0.223985
# Train Epoch: 20 [8960/9886 (90%)]	Loss: 0.154064
# Total running time: 124.99013876914978
#
# Test set: Avg. loss: 0.0049, Accuracy: 454/521 (87%)
#
# Training Resnet34
# Train Epoch: 21 [0/9886 (0%)]	Loss: 0.157576
# Train Epoch: 21 [1280/9886 (13%)]	Loss: 0.146548
# Train Epoch: 21 [2560/9886 (26%)]	Loss: 0.199614
# Train Epoch: 21 [3840/9886 (38%)]	Loss: 0.118777
# Train Epoch: 21 [5120/9886 (51%)]	Loss: 0.166018
# Train Epoch: 21 [6400/9886 (64%)]	Loss: 0.128702
# Train Epoch: 21 [7680/9886 (77%)]	Loss: 0.106306
# Train Epoch: 21 [8960/9886 (90%)]	Loss: 0.123395
# Total running time: 125.09879326820374
#
# Test set: Avg. loss: 0.0047, Accuracy: 458/521 (88%)
#
# Training Resnet34
# Train Epoch: 22 [0/9886 (0%)]	Loss: 0.139381
# Train Epoch: 22 [1280/9886 (13%)]	Loss: 0.133993
# Train Epoch: 22 [2560/9886 (26%)]	Loss: 0.118885
# Train Epoch: 22 [3840/9886 (38%)]	Loss: 0.125754
# Train Epoch: 22 [5120/9886 (51%)]	Loss: 0.110872
# Train Epoch: 22 [6400/9886 (64%)]	Loss: 0.151722
# Train Epoch: 22 [7680/9886 (77%)]	Loss: 0.120097
# Train Epoch: 22 [8960/9886 (90%)]	Loss: 0.170226
# Total running time: 124.97230982780457
#
# Test set: Avg. loss: 0.0046, Accuracy: 457/521 (88%)
#
# Training Resnet34
# Train Epoch: 23 [0/9886 (0%)]	Loss: 0.124857
# Train Epoch: 23 [1280/9886 (13%)]	Loss: 0.086991
# Train Epoch: 23 [2560/9886 (26%)]	Loss: 0.157104
# Train Epoch: 23 [3840/9886 (38%)]	Loss: 0.130383
# Train Epoch: 23 [5120/9886 (51%)]	Loss: 0.102960
# Train Epoch: 23 [6400/9886 (64%)]	Loss: 0.137551
# Train Epoch: 23 [7680/9886 (77%)]	Loss: 0.097629
# Train Epoch: 23 [8960/9886 (90%)]	Loss: 0.127721
# Total running time: 124.95530319213867
#
# Test set: Avg. loss: 0.0045, Accuracy: 459/521 (88%)
#
# Training Resnet34
# Train Epoch: 24 [0/9886 (0%)]	Loss: 0.080824
# Train Epoch: 24 [1280/9886 (13%)]	Loss: 0.145190
# Train Epoch: 24 [2560/9886 (26%)]	Loss: 0.165375
# Train Epoch: 24 [3840/9886 (38%)]	Loss: 0.122064
# Train Epoch: 24 [5120/9886 (51%)]	Loss: 0.119740
# Train Epoch: 24 [6400/9886 (64%)]	Loss: 0.114773
# Train Epoch: 24 [7680/9886 (77%)]	Loss: 0.096794
# Train Epoch: 24 [8960/9886 (90%)]	Loss: 0.122230
# Total running time: 126.00190305709839
#
# Test set: Avg. loss: 0.0044, Accuracy: 460/521 (88%)
#
# Training Resnet34
# Train Epoch: 25 [0/9886 (0%)]	Loss: 0.075404
# Train Epoch: 25 [1280/9886 (13%)]	Loss: 0.112439
# Train Epoch: 25 [2560/9886 (26%)]	Loss: 0.091828
# Train Epoch: 25 [3840/9886 (38%)]	Loss: 0.076084
# Train Epoch: 25 [5120/9886 (51%)]	Loss: 0.119428
# Train Epoch: 25 [6400/9886 (64%)]	Loss: 0.099517
# Train Epoch: 25 [7680/9886 (77%)]	Loss: 0.104062
# Train Epoch: 25 [8960/9886 (90%)]	Loss: 0.089655
# Total running time: 124.58816981315613
#
# Test set: Avg. loss: 0.0043, Accuracy: 461/521 (88%)
#
# Training Resnet34
# Train Epoch: 26 [0/9886 (0%)]	Loss: 0.095119
# Train Epoch: 26 [1280/9886 (13%)]	Loss: 0.093303
# Train Epoch: 26 [2560/9886 (26%)]	Loss: 0.085747
# Train Epoch: 26 [3840/9886 (38%)]	Loss: 0.080957
# Train Epoch: 26 [5120/9886 (51%)]	Loss: 0.078794
# Train Epoch: 26 [6400/9886 (64%)]	Loss: 0.079985
# Train Epoch: 26 [7680/9886 (77%)]	Loss: 0.079837
# Train Epoch: 26 [8960/9886 (90%)]	Loss: 0.153534
# Total running time: 126.30296015739441
#
# Test set: Avg. loss: 0.0043, Accuracy: 463/521 (89%)
#
# Training Resnet34
# Train Epoch: 27 [0/9886 (0%)]	Loss: 0.111070
# Train Epoch: 27 [1280/9886 (13%)]	Loss: 0.086755
# Train Epoch: 27 [2560/9886 (26%)]	Loss: 0.099450
# Train Epoch: 27 [3840/9886 (38%)]	Loss: 0.068112
# Train Epoch: 27 [5120/9886 (51%)]	Loss: 0.080313
# Train Epoch: 27 [6400/9886 (64%)]	Loss: 0.072784
# Train Epoch: 27 [7680/9886 (77%)]	Loss: 0.066465
# Train Epoch: 27 [8960/9886 (90%)]	Loss: 0.085852
# Total running time: 126.32241702079773
#
# Test set: Avg. loss: 0.0042, Accuracy: 464/521 (89%)
#
# Training Resnet34
# Train Epoch: 28 [0/9886 (0%)]	Loss: 0.062939
# Train Epoch: 28 [1280/9886 (13%)]	Loss: 0.083298
# Train Epoch: 28 [2560/9886 (26%)]	Loss: 0.062555
# Train Epoch: 28 [3840/9886 (38%)]	Loss: 0.066663
# Train Epoch: 28 [5120/9886 (51%)]	Loss: 0.103047
# Train Epoch: 28 [6400/9886 (64%)]	Loss: 0.068344
# Train Epoch: 28 [7680/9886 (77%)]	Loss: 0.052246
# Train Epoch: 28 [8960/9886 (90%)]	Loss: 0.102406
# Total running time: 126.73693823814392
#
# Test set: Avg. loss: 0.0042, Accuracy: 463/521 (89%)
#
# Training Resnet34
# Train Epoch: 29 [0/9886 (0%)]	Loss: 0.070050
# Train Epoch: 29 [1280/9886 (13%)]	Loss: 0.091563
# Train Epoch: 29 [2560/9886 (26%)]	Loss: 0.104885
# Train Epoch: 29 [3840/9886 (38%)]	Loss: 0.061915
# Train Epoch: 29 [5120/9886 (51%)]	Loss: 0.085306
# Train Epoch: 29 [6400/9886 (64%)]	Loss: 0.072978
# Train Epoch: 29 [7680/9886 (77%)]	Loss: 0.069720
# Train Epoch: 29 [8960/9886 (90%)]	Loss: 0.058902
# Total running time: 124.77066564559937
#
# Test set: Avg. loss: 0.0041, Accuracy: 465/521 (89%)
#
# Training Resnet34
# Train Epoch: 30 [0/9886 (0%)]	Loss: 0.070449
# Train Epoch: 30 [1280/9886 (13%)]	Loss: 0.055884
# Train Epoch: 30 [2560/9886 (26%)]	Loss: 0.063796
# Train Epoch: 30 [3840/9886 (38%)]	Loss: 0.086035
# Train Epoch: 30 [5120/9886 (51%)]	Loss: 0.063856
# Train Epoch: 30 [6400/9886 (64%)]	Loss: 0.061856
# Train Epoch: 30 [7680/9886 (77%)]	Loss: 0.086290
# Train Epoch: 30 [8960/9886 (90%)]	Loss: 0.059676
# Total running time: 125.57956266403198
#
# Test set: Avg. loss: 0.0040, Accuracy: 465/521 (89%)
#
# Training Resnet34
# Train Epoch: 31 [0/9886 (0%)]	Loss: 0.085250
# Train Epoch: 31 [1280/9886 (13%)]	Loss: 0.073262
# Train Epoch: 31 [2560/9886 (26%)]	Loss: 0.055673
# Train Epoch: 31 [3840/9886 (38%)]	Loss: 0.057754
# Train Epoch: 31 [5120/9886 (51%)]	Loss: 0.067496
# Train Epoch: 31 [6400/9886 (64%)]	Loss: 0.050642
# Train Epoch: 31 [7680/9886 (77%)]	Loss: 0.040542
# Train Epoch: 31 [8960/9886 (90%)]	Loss: 0.054947
# Total running time: 125.07913136482239
#
# Test set: Avg. loss: 0.0041, Accuracy: 467/521 (90%)
#
# Training Resnet34
# Train Epoch: 32 [0/9886 (0%)]	Loss: 0.058771
# Train Epoch: 32 [1280/9886 (13%)]	Loss: 0.053430
# Train Epoch: 32 [2560/9886 (26%)]	Loss: 0.051018
# Train Epoch: 32 [3840/9886 (38%)]	Loss: 0.047422
# Train Epoch: 32 [5120/9886 (51%)]	Loss: 0.055527
# Train Epoch: 32 [6400/9886 (64%)]	Loss: 0.041930
# Train Epoch: 32 [7680/9886 (77%)]	Loss: 0.049881
# Train Epoch: 32 [8960/9886 (90%)]	Loss: 0.046898
# Total running time: 126.61128878593445
#
# Test set: Avg. loss: 0.0040, Accuracy: 466/521 (89%)
#
# Training Resnet34
# Train Epoch: 33 [0/9886 (0%)]	Loss: 0.047474
# Train Epoch: 33 [1280/9886 (13%)]	Loss: 0.047648
# Train Epoch: 33 [2560/9886 (26%)]	Loss: 0.050539
# Train Epoch: 33 [3840/9886 (38%)]	Loss: 0.037329
# Train Epoch: 33 [5120/9886 (51%)]	Loss: 0.062674
# Train Epoch: 33 [6400/9886 (64%)]	Loss: 0.050742
# Train Epoch: 33 [7680/9886 (77%)]	Loss: 0.043983
# Train Epoch: 33 [8960/9886 (90%)]	Loss: 0.041201
# Total running time: 125.28008460998535
#
# Test set: Avg. loss: 0.0039, Accuracy: 470/521 (90%)
#
# Training Resnet34
# Train Epoch: 34 [0/9886 (0%)]	Loss: 0.053446
# Train Epoch: 34 [1280/9886 (13%)]	Loss: 0.032857
# Train Epoch: 34 [2560/9886 (26%)]	Loss: 0.040834
# Train Epoch: 34 [3840/9886 (38%)]	Loss: 0.056606
# Train Epoch: 34 [5120/9886 (51%)]	Loss: 0.041699
# Train Epoch: 34 [6400/9886 (64%)]	Loss: 0.044808
# Train Epoch: 34 [7680/9886 (77%)]	Loss: 0.043550
# Train Epoch: 34 [8960/9886 (90%)]	Loss: 0.054859
# Total running time: 126.9500961303711
#
# Test set: Avg. loss: 0.0039, Accuracy: 468/521 (90%)
#
# Training Resnet34
# Train Epoch: 35 [0/9886 (0%)]	Loss: 0.054703
# Train Epoch: 35 [1280/9886 (13%)]	Loss: 0.037548
# Train Epoch: 35 [2560/9886 (26%)]	Loss: 0.031346
# Train Epoch: 35 [3840/9886 (38%)]	Loss: 0.035488
# Train Epoch: 35 [5120/9886 (51%)]	Loss: 0.045310
# Train Epoch: 35 [6400/9886 (64%)]	Loss: 0.045837
# Train Epoch: 35 [7680/9886 (77%)]	Loss: 0.039931
# Train Epoch: 35 [8960/9886 (90%)]	Loss: 0.047164
# Total running time: 125.0812120437622
#
# Test set: Avg. loss: 0.0039, Accuracy: 468/521 (90%)
#
# Training Resnet34
# Train Epoch: 36 [0/9886 (0%)]	Loss: 0.034792
# Train Epoch: 36 [1280/9886 (13%)]	Loss: 0.043772
# Train Epoch: 36 [2560/9886 (26%)]	Loss: 0.047781
# Train Epoch: 36 [3840/9886 (38%)]	Loss: 0.039605
# Train Epoch: 36 [5120/9886 (51%)]	Loss: 0.031056
# Train Epoch: 36 [6400/9886 (64%)]	Loss: 0.039179
# Train Epoch: 36 [7680/9886 (77%)]	Loss: 0.043002
# Train Epoch: 36 [8960/9886 (90%)]	Loss: 0.051702
# Total running time: 125.14373183250427
#
# Test set: Avg. loss: 0.0038, Accuracy: 469/521 (90%)
#
# Training Resnet34
# Train Epoch: 37 [0/9886 (0%)]	Loss: 0.036701
# Train Epoch: 37 [1280/9886 (13%)]	Loss: 0.041779
# Train Epoch: 37 [2560/9886 (26%)]	Loss: 0.044871
# Train Epoch: 37 [3840/9886 (38%)]	Loss: 0.034293
# Train Epoch: 37 [5120/9886 (51%)]	Loss: 0.039207
# Train Epoch: 37 [6400/9886 (64%)]	Loss: 0.040229
# Train Epoch: 37 [7680/9886 (77%)]	Loss: 0.044612
# Train Epoch: 37 [8960/9886 (90%)]	Loss: 0.036523
# Total running time: 125.71562337875366
#
# Test set: Avg. loss: 0.0038, Accuracy: 470/521 (90%)
#
# Training Resnet34
# Train Epoch: 38 [0/9886 (0%)]	Loss: 0.049394
# Train Epoch: 38 [1280/9886 (13%)]	Loss: 0.020967
# Train Epoch: 38 [2560/9886 (26%)]	Loss: 0.024555
# Train Epoch: 38 [3840/9886 (38%)]	Loss: 0.040161
# Train Epoch: 38 [5120/9886 (51%)]	Loss: 0.028437
# Train Epoch: 38 [6400/9886 (64%)]	Loss: 0.035054
# Train Epoch: 38 [7680/9886 (77%)]	Loss: 0.032157
# Train Epoch: 38 [8960/9886 (90%)]	Loss: 0.028982
# Total running time: 125.90685176849365
#
# Test set: Avg. loss: 0.0037, Accuracy: 471/521 (90%)
#
# Training Resnet34
# Train Epoch: 39 [0/9886 (0%)]	Loss: 0.025236
# Train Epoch: 39 [1280/9886 (13%)]	Loss: 0.024554
# Train Epoch: 39 [2560/9886 (26%)]	Loss: 0.036608
# Train Epoch: 39 [3840/9886 (38%)]	Loss: 0.023133
# Train Epoch: 39 [5120/9886 (51%)]	Loss: 0.029984
# Train Epoch: 39 [6400/9886 (64%)]	Loss: 0.037726
# Train Epoch: 39 [7680/9886 (77%)]	Loss: 0.035839
# Train Epoch: 39 [8960/9886 (90%)]	Loss: 0.030568
# Total running time: 126.39685726165771
#
# Test set: Avg. loss: 0.0038, Accuracy: 474/521 (91%)
#
# Training Resnet34
# Train Epoch: 40 [0/9886 (0%)]	Loss: 0.028473
# Train Epoch: 40 [1280/9886 (13%)]	Loss: 0.028341
# Train Epoch: 40 [2560/9886 (26%)]	Loss: 0.032211
# Train Epoch: 40 [3840/9886 (38%)]	Loss: 0.034895
# Train Epoch: 40 [5120/9886 (51%)]	Loss: 0.034053
# Train Epoch: 40 [6400/9886 (64%)]	Loss: 0.032060
# Train Epoch: 40 [7680/9886 (77%)]	Loss: 0.027120
# Train Epoch: 40 [8960/9886 (90%)]	Loss: 0.027549
# Total running time: 125.7607352733612
#
# Test set: Avg. loss: 0.0037, Accuracy: 469/521 (90%)
#
# Training Resnet34
# Train Epoch: 41 [0/9886 (0%)]	Loss: 0.030634
# Train Epoch: 41 [1280/9886 (13%)]	Loss: 0.025908
# Train Epoch: 41 [2560/9886 (26%)]	Loss: 0.029293
# Train Epoch: 41 [3840/9886 (38%)]	Loss: 0.036411
# Train Epoch: 41 [5120/9886 (51%)]	Loss: 0.016022
# Train Epoch: 41 [6400/9886 (64%)]	Loss: 0.035973
# Train Epoch: 41 [7680/9886 (77%)]	Loss: 0.023069
# Train Epoch: 41 [8960/9886 (90%)]	Loss: 0.037444
# Total running time: 125.21237587928772
#
# Test set: Avg. loss: 0.0037, Accuracy: 472/521 (91%)
#
# Training Resnet34
# Train Epoch: 42 [0/9886 (0%)]	Loss: 0.041710
# Train Epoch: 42 [1280/9886 (13%)]	Loss: 0.028972
# Train Epoch: 42 [2560/9886 (26%)]	Loss: 0.027185
# Train Epoch: 42 [3840/9886 (38%)]	Loss: 0.025591
# Train Epoch: 42 [5120/9886 (51%)]	Loss: 0.027446
# Train Epoch: 42 [6400/9886 (64%)]	Loss: 0.029504
# Train Epoch: 42 [7680/9886 (77%)]	Loss: 0.022704
# Train Epoch: 42 [8960/9886 (90%)]	Loss: 0.022777
# Total running time: 126.31726861000061
#
# Test set: Avg. loss: 0.0037, Accuracy: 470/521 (90%)
#
# Training Resnet34
# Train Epoch: 43 [0/9886 (0%)]	Loss: 0.027939
# Train Epoch: 43 [1280/9886 (13%)]	Loss: 0.025086
# Train Epoch: 43 [2560/9886 (26%)]	Loss: 0.021699
# Train Epoch: 43 [3840/9886 (38%)]	Loss: 0.028317
# Train Epoch: 43 [5120/9886 (51%)]	Loss: 0.023928
# Train Epoch: 43 [6400/9886 (64%)]	Loss: 0.031453
# Train Epoch: 43 [7680/9886 (77%)]	Loss: 0.019870
# Train Epoch: 43 [8960/9886 (90%)]	Loss: 0.023359
# Total running time: 125.36089825630188
#
# Test set: Avg. loss: 0.0037, Accuracy: 473/521 (91%)
#
# Training Resnet34
# Train Epoch: 44 [0/9886 (0%)]	Loss: 0.025578
# Train Epoch: 44 [1280/9886 (13%)]	Loss: 0.020486
# Train Epoch: 44 [2560/9886 (26%)]	Loss: 0.018081
# Train Epoch: 44 [3840/9886 (38%)]	Loss: 0.024176
# Train Epoch: 44 [5120/9886 (51%)]	Loss: 0.028396
# Train Epoch: 44 [6400/9886 (64%)]	Loss: 0.021795
# Train Epoch: 44 [7680/9886 (77%)]	Loss: 0.014860
# Train Epoch: 44 [8960/9886 (90%)]	Loss: 0.021219
# Total running time: 125.17154312133789
#
# Test set: Avg. loss: 0.0037, Accuracy: 471/521 (90%)
#
# Training Resnet34
# Train Epoch: 45 [0/9886 (0%)]	Loss: 0.020405
# Train Epoch: 45 [1280/9886 (13%)]	Loss: 0.018127
# Train Epoch: 45 [2560/9886 (26%)]	Loss: 0.019318
# Train Epoch: 45 [3840/9886 (38%)]	Loss: 0.040706
# Train Epoch: 45 [5120/9886 (51%)]	Loss: 0.020438
# Train Epoch: 45 [6400/9886 (64%)]	Loss: 0.023229
# Train Epoch: 45 [7680/9886 (77%)]	Loss: 0.023087
# Train Epoch: 45 [8960/9886 (90%)]	Loss: 0.024177
# Total running time: 125.50968360900879
#
# Test set: Avg. loss: 0.0036, Accuracy: 474/521 (91%)
#
# Training Resnet34
# Train Epoch: 46 [0/9886 (0%)]	Loss: 0.018070
# Train Epoch: 46 [1280/9886 (13%)]	Loss: 0.018648
# Train Epoch: 46 [2560/9886 (26%)]	Loss: 0.024741
# Train Epoch: 46 [3840/9886 (38%)]	Loss: 0.022209
# Train Epoch: 46 [5120/9886 (51%)]	Loss: 0.022951
# Train Epoch: 46 [6400/9886 (64%)]	Loss: 0.016579
# Train Epoch: 46 [7680/9886 (77%)]	Loss: 0.023176
# Train Epoch: 46 [8960/9886 (90%)]	Loss: 0.021817
# Total running time: 124.86415910720825
#
# Test set: Avg. loss: 0.0036, Accuracy: 473/521 (91%)
#
# Training Resnet34
# Train Epoch: 47 [0/9886 (0%)]	Loss: 0.015254
# Train Epoch: 47 [1280/9886 (13%)]	Loss: 0.021140
# Train Epoch: 47 [2560/9886 (26%)]	Loss: 0.013133
# Train Epoch: 47 [3840/9886 (38%)]	Loss: 0.014575
# Train Epoch: 47 [5120/9886 (51%)]	Loss: 0.019420
# Train Epoch: 47 [6400/9886 (64%)]	Loss: 0.021117
# Train Epoch: 47 [7680/9886 (77%)]	Loss: 0.022973
# Train Epoch: 47 [8960/9886 (90%)]	Loss: 0.026223
# Total running time: 125.58697724342346
#
# Test set: Avg. loss: 0.0036, Accuracy: 470/521 (90%)
#
# Training Resnet34
# Train Epoch: 48 [0/9886 (0%)]	Loss: 0.016270
# Train Epoch: 48 [1280/9886 (13%)]	Loss: 0.020143
# Train Epoch: 48 [2560/9886 (26%)]	Loss: 0.016027
# Train Epoch: 48 [3840/9886 (38%)]	Loss: 0.022695
# Train Epoch: 48 [5120/9886 (51%)]	Loss: 0.019895
# Train Epoch: 48 [6400/9886 (64%)]	Loss: 0.017336
# Train Epoch: 48 [7680/9886 (77%)]	Loss: 0.023196
# Train Epoch: 48 [8960/9886 (90%)]	Loss: 0.017552
# Total running time: 123.98568391799927
#
# Test set: Avg. loss: 0.0036, Accuracy: 471/521 (90%)
#
# Training Resnet34
# Train Epoch: 49 [0/9886 (0%)]	Loss: 0.025821
# Train Epoch: 49 [1280/9886 (13%)]	Loss: 0.021976
# Train Epoch: 49 [2560/9886 (26%)]	Loss: 0.013185
# Train Epoch: 49 [3840/9886 (38%)]	Loss: 0.018017
# Train Epoch: 49 [5120/9886 (51%)]	Loss: 0.019351
# Train Epoch: 49 [6400/9886 (64%)]	Loss: 0.019987
# Train Epoch: 49 [7680/9886 (77%)]	Loss: 0.014804
# Train Epoch: 49 [8960/9886 (90%)]	Loss: 0.023023
# Total running time: 126.63604474067688
#
# Test set: Avg. loss: 0.0036, Accuracy: 474/521 (91%)
#
# Training Resnet34
# Train Epoch: 50 [0/9886 (0%)]	Loss: 0.020405
# Train Epoch: 50 [1280/9886 (13%)]	Loss: 0.024229
# Train Epoch: 50 [2560/9886 (26%)]	Loss: 0.014426
# Train Epoch: 50 [3840/9886 (38%)]	Loss: 0.020267
# Train Epoch: 50 [5120/9886 (51%)]	Loss: 0.019669
# Train Epoch: 50 [6400/9886 (64%)]	Loss: 0.018440
# Train Epoch: 50 [7680/9886 (77%)]	Loss: 0.020885
# Train Epoch: 50 [8960/9886 (90%)]	Loss: 0.011927
# Total running time: 125.00704741477966
#
# Test set: Avg. loss: 0.0036, Accuracy: 473/521 (91%)
#
# accuracy_resnet34 [37.61996078491211, 48.36852264404297, 54.894432067871094, 59.88483428955078, 63.91554641723633, 66.6026840209961, 70.05757904052734, 73.3205337524414, 75.4318618774414, 77.15930938720703, 78.50287628173828, 80.61420440673828, 82.3416519165039, 82.53358459472656, 84.64491271972656, 84.64491271972656, 85.79653930664062, 86.180419921875, 86.75623321533203, 87.1401138305664, 87.90786743164062, 87.71592712402344, 88.09980773925781, 88.291748046875, 88.48368072509766, 88.86756134033203, 89.05950164794922, 88.86756134033203, 89.25143432617188, 89.25143432617188, 89.63531494140625, 89.44337463378906, 90.21112823486328, 89.82725524902344, 89.82725524902344, 90.0191879272461, 90.21112823486328, 90.40306854248047, 90.9788818359375, 90.0191879272461, 90.59500885009766, 90.21112823486328, 90.78694915771484, 90.40306854248047, 90.9788818359375, 90.78694915771484, 90.21112823486328, 90.40306854248047, 90.9788818359375, 90.78694915771484]
# test_targets
# tensor([4, 9, 4, 8, 9, 5, 9, 7, 4, 1, 9, 7, 8, 7, 7, 9, 3, 1, 3, 8, 9, 6, 7, 8,
#         3, 7, 4, 5, 3, 4, 5, 3, 6, 5, 8, 5, 9, 8, 3, 8, 9, 5, 8, 9, 7, 6, 7, 0,
#         5, 4, 8, 1, 3, 9, 5, 6, 8, 4, 7, 7, 8, 6, 7, 0, 5, 5, 3, 7, 1, 7, 4, 9,
#         7, 3, 3, 3, 6, 3, 0, 3, 5, 9, 7, 3, 3, 3, 8, 4, 8, 8, 3, 9, 4, 8, 8, 3,
#         0, 5, 3, 4, 7, 5, 8, 6, 3, 7, 5, 7, 8, 5, 8, 7, 7, 7, 7, 5, 3, 5, 5, 5,
#         8, 7, 3, 8, 5, 8, 8, 5])
# test_images shape torch.Size([128, 3, 224, 224])
#
# Test set: Avg. loss: 0.0036, Accuracy: 473/521 (91%)
#
# ../input/paddy-doctor/train_images/brown_spot/101853.jpg
# ../input/paddy-doctor/train_images/tungro/105016.jpg
# ../input/paddy-doctor/train_images/brown_spot/103031.jpg
# ../input/paddy-doctor/train_images/normal/103814.jpg
# ../input/paddy-doctor/train_images/tungro/107957.jpg
# ../input/paddy-doctor/train_images/dead_heart/106942.jpg
# ../input/paddy-doctor/train_images/tungro/107951.jpg
# ../input/paddy-doctor/train_images/hispa/101127.jpg
# ../input/paddy-doctor/train_images/brown_spot/107362.jpg
# ../input/paddy-doctor/train_images/bacterial_leaf_streak/109268.jpg
# Training Resnet18
# Train Epoch: 1 [0/9886 (0%)]	Loss: 2.558009
# Train Epoch: 1 [1280/9886 (13%)]	Loss: 2.265976
# Train Epoch: 1 [2560/9886 (26%)]	Loss: 2.062356
# Train Epoch: 1 [3840/9886 (38%)]	Loss: 2.081496
# Train Epoch: 1 [5120/9886 (51%)]	Loss: 2.091929
# Train Epoch: 1 [6400/9886 (64%)]	Loss: 1.974563
# Train Epoch: 1 [7680/9886 (77%)]	Loss: 1.979942
# Train Epoch: 1 [8960/9886 (90%)]	Loss: 1.972550
# Total running time: 102.507169008255
#
# Test set: Avg. loss: 0.0186, Accuracy: 195/521 (37%)
#
# Training Resnet18
# Train Epoch: 2 [0/9886 (0%)]	Loss: 2.058205
# Train Epoch: 2 [1280/9886 (13%)]	Loss: 1.913232
# Train Epoch: 2 [2560/9886 (26%)]	Loss: 1.892339
# Train Epoch: 2 [3840/9886 (38%)]	Loss: 1.785203
# Train Epoch: 2 [5120/9886 (51%)]	Loss: 1.794884
# Train Epoch: 2 [6400/9886 (64%)]	Loss: 1.700759
# Train Epoch: 2 [7680/9886 (77%)]	Loss: 1.777897
# Train Epoch: 2 [8960/9886 (90%)]	Loss: 1.667128
# Total running time: 102.38805222511292
#
# Test set: Avg. loss: 0.0169, Accuracy: 235/521 (45%)
#
# Training Resnet18
# Train Epoch: 3 [0/9886 (0%)]	Loss: 1.750025
# Train Epoch: 3 [1280/9886 (13%)]	Loss: 1.662007
# Train Epoch: 3 [2560/9886 (26%)]	Loss: 1.785157
# Train Epoch: 3 [3840/9886 (38%)]	Loss: 1.613680
# Train Epoch: 3 [5120/9886 (51%)]	Loss: 1.598463
# Train Epoch: 3 [6400/9886 (64%)]	Loss: 1.613604
# Train Epoch: 3 [7680/9886 (77%)]	Loss: 1.638387
# Train Epoch: 3 [8960/9886 (90%)]	Loss: 1.554847
# Total running time: 102.10793781280518
#
# Test set: Avg. loss: 0.0155, Accuracy: 262/521 (50%)
#
# Training Resnet18
# Train Epoch: 4 [0/9886 (0%)]	Loss: 1.466763
# Train Epoch: 4 [1280/9886 (13%)]	Loss: 1.561860
# Train Epoch: 4 [2560/9886 (26%)]	Loss: 1.489277
# Train Epoch: 4 [3840/9886 (38%)]	Loss: 1.511921
# Train Epoch: 4 [5120/9886 (51%)]	Loss: 1.428133
# Train Epoch: 4 [6400/9886 (64%)]	Loss: 1.413685
# Train Epoch: 4 [7680/9886 (77%)]	Loss: 1.382929
# Train Epoch: 4 [8960/9886 (90%)]	Loss: 1.490112
# Total running time: 101.19628381729126
#
# Test set: Avg. loss: 0.0139, Accuracy: 281/521 (54%)
#
# Training Resnet18
# Train Epoch: 5 [0/9886 (0%)]	Loss: 1.307292
# Train Epoch: 5 [1280/9886 (13%)]	Loss: 1.389530
# Train Epoch: 5 [2560/9886 (26%)]	Loss: 1.258214
# Train Epoch: 5 [3840/9886 (38%)]	Loss: 1.408256
# Train Epoch: 5 [5120/9886 (51%)]	Loss: 1.316276
# Train Epoch: 5 [6400/9886 (64%)]	Loss: 1.225993
# Train Epoch: 5 [7680/9886 (77%)]	Loss: 1.303627
# Train Epoch: 5 [8960/9886 (90%)]	Loss: 1.318379
# Total running time: 101.87448024749756
#
# Test set: Avg. loss: 0.0127, Accuracy: 313/521 (60%)
#
# Training Resnet18
# Train Epoch: 6 [0/9886 (0%)]	Loss: 1.292153
# Train Epoch: 6 [1280/9886 (13%)]	Loss: 1.294503
# Train Epoch: 6 [2560/9886 (26%)]	Loss: 1.244991
# Train Epoch: 6 [3840/9886 (38%)]	Loss: 1.144269
# Train Epoch: 6 [5120/9886 (51%)]	Loss: 1.232295
# Train Epoch: 6 [6400/9886 (64%)]	Loss: 1.134608
# Train Epoch: 6 [7680/9886 (77%)]	Loss: 1.170733
# Train Epoch: 6 [8960/9886 (90%)]	Loss: 1.121919
# Total running time: 102.04341673851013
#
# Test set: Avg. loss: 0.0116, Accuracy: 327/521 (63%)
#
# Training Resnet18
# Train Epoch: 7 [0/9886 (0%)]	Loss: 1.175022
# Train Epoch: 7 [1280/9886 (13%)]	Loss: 1.039111
# Train Epoch: 7 [2560/9886 (26%)]	Loss: 1.062846
# Train Epoch: 7 [3840/9886 (38%)]	Loss: 1.049679
# Train Epoch: 7 [5120/9886 (51%)]	Loss: 1.130461
# Train Epoch: 7 [6400/9886 (64%)]	Loss: 0.949177
# Train Epoch: 7 [7680/9886 (77%)]	Loss: 1.078961
# Train Epoch: 7 [8960/9886 (90%)]	Loss: 1.150875
# Total running time: 101.27607131004333
#
# Test set: Avg. loss: 0.0108, Accuracy: 348/521 (67%)
#
# Training Resnet18
# Train Epoch: 8 [0/9886 (0%)]	Loss: 0.869256
# Train Epoch: 8 [1280/9886 (13%)]	Loss: 1.048558
# Train Epoch: 8 [2560/9886 (26%)]	Loss: 0.889240
# Train Epoch: 8 [3840/9886 (38%)]	Loss: 0.966074
# Train Epoch: 8 [5120/9886 (51%)]	Loss: 0.938153
# Train Epoch: 8 [6400/9886 (64%)]	Loss: 1.016326
# Train Epoch: 8 [7680/9886 (77%)]	Loss: 0.950912
# Train Epoch: 8 [8960/9886 (90%)]	Loss: 0.976721
# Total running time: 101.82828879356384
#
# Test set: Avg. loss: 0.0100, Accuracy: 358/521 (69%)
#
# Training Resnet18
# Train Epoch: 9 [0/9886 (0%)]	Loss: 1.095839
# Train Epoch: 9 [1280/9886 (13%)]	Loss: 0.937922
# Train Epoch: 9 [2560/9886 (26%)]	Loss: 0.777236
# Train Epoch: 9 [3840/9886 (38%)]	Loss: 0.807179
# Train Epoch: 9 [5120/9886 (51%)]	Loss: 1.101504
# Train Epoch: 9 [6400/9886 (64%)]	Loss: 0.868385
# Train Epoch: 9 [7680/9886 (77%)]	Loss: 0.881444
# Train Epoch: 9 [8960/9886 (90%)]	Loss: 0.733839
# Total running time: 101.10065817832947
#
# Test set: Avg. loss: 0.0094, Accuracy: 362/521 (69%)
#
# Training Resnet18
# Train Epoch: 10 [0/9886 (0%)]	Loss: 0.708257
# Train Epoch: 10 [1280/9886 (13%)]	Loss: 0.771745
# Train Epoch: 10 [2560/9886 (26%)]	Loss: 0.825987
# Train Epoch: 10 [3840/9886 (38%)]	Loss: 0.772459
# Train Epoch: 10 [5120/9886 (51%)]	Loss: 0.953858
# Train Epoch: 10 [6400/9886 (64%)]	Loss: 0.793592
# Train Epoch: 10 [7680/9886 (77%)]	Loss: 0.755833
# Train Epoch: 10 [8960/9886 (90%)]	Loss: 0.706740
# Total running time: 101.03051900863647
#
# Test set: Avg. loss: 0.0088, Accuracy: 379/521 (73%)
#
# Training Resnet18
# Train Epoch: 11 [0/9886 (0%)]	Loss: 0.852701
# Train Epoch: 11 [1280/9886 (13%)]	Loss: 0.769901
# Train Epoch: 11 [2560/9886 (26%)]	Loss: 0.727697
# Train Epoch: 11 [3840/9886 (38%)]	Loss: 0.788151
# Train Epoch: 11 [5120/9886 (51%)]	Loss: 0.718740
# Train Epoch: 11 [6400/9886 (64%)]	Loss: 0.765534
# Train Epoch: 11 [7680/9886 (77%)]	Loss: 0.768048
# Train Epoch: 11 [8960/9886 (90%)]	Loss: 0.744494
# Total running time: 101.46534943580627
#
# Test set: Avg. loss: 0.0084, Accuracy: 384/521 (74%)
#
# Training Resnet18
# Train Epoch: 12 [0/9886 (0%)]	Loss: 0.793479
# Train Epoch: 12 [1280/9886 (13%)]	Loss: 0.654024
# Train Epoch: 12 [2560/9886 (26%)]	Loss: 0.785315
# Train Epoch: 12 [3840/9886 (38%)]	Loss: 0.654463
# Train Epoch: 12 [5120/9886 (51%)]	Loss: 0.666783
# Train Epoch: 12 [6400/9886 (64%)]	Loss: 0.647944
# Train Epoch: 12 [7680/9886 (77%)]	Loss: 0.733784
# Train Epoch: 12 [8960/9886 (90%)]	Loss: 0.623006
# Total running time: 101.56678867340088
#
# Test set: Avg. loss: 0.0079, Accuracy: 396/521 (76%)
#
# Training Resnet18
# Train Epoch: 13 [0/9886 (0%)]	Loss: 0.637882
# Train Epoch: 13 [1280/9886 (13%)]	Loss: 0.652797
# Train Epoch: 13 [2560/9886 (26%)]	Loss: 0.630449
# Train Epoch: 13 [3840/9886 (38%)]	Loss: 0.653360
# Train Epoch: 13 [5120/9886 (51%)]	Loss: 0.561973
# Train Epoch: 13 [6400/9886 (64%)]	Loss: 0.599944
# Train Epoch: 13 [7680/9886 (77%)]	Loss: 0.584427
# Train Epoch: 13 [8960/9886 (90%)]	Loss: 0.651443
# Total running time: 101.6017415523529
#
# Test set: Avg. loss: 0.0075, Accuracy: 401/521 (77%)
#
# Training Resnet18
# Train Epoch: 14 [0/9886 (0%)]	Loss: 0.542878
# Train Epoch: 14 [1280/9886 (13%)]	Loss: 0.601382
# Train Epoch: 14 [2560/9886 (26%)]	Loss: 0.515945
# Train Epoch: 14 [3840/9886 (38%)]	Loss: 0.625433
# Train Epoch: 14 [5120/9886 (51%)]	Loss: 0.481437
# Train Epoch: 14 [6400/9886 (64%)]	Loss: 0.679621
# Train Epoch: 14 [7680/9886 (77%)]	Loss: 0.661749
# Train Epoch: 14 [8960/9886 (90%)]	Loss: 0.587965
# Total running time: 101.61355710029602
#
# Test set: Avg. loss: 0.0072, Accuracy: 409/521 (79%)
#
# Training Resnet18
# Train Epoch: 15 [0/9886 (0%)]	Loss: 0.581633
# Train Epoch: 15 [1280/9886 (13%)]	Loss: 0.561615
# Train Epoch: 15 [2560/9886 (26%)]	Loss: 0.573852
# Train Epoch: 15 [3840/9886 (38%)]	Loss: 0.511542
# Train Epoch: 15 [5120/9886 (51%)]	Loss: 0.532011
# Train Epoch: 15 [6400/9886 (64%)]	Loss: 0.621523
# Train Epoch: 15 [7680/9886 (77%)]	Loss: 0.469198
# Train Epoch: 15 [8960/9886 (90%)]	Loss: 0.520976
# Total running time: 101.75164103507996
#
# Test set: Avg. loss: 0.0070, Accuracy: 414/521 (79%)
#
# Training Resnet18
# Train Epoch: 16 [0/9886 (0%)]	Loss: 0.449860
# Train Epoch: 16 [1280/9886 (13%)]	Loss: 0.618287
# Train Epoch: 16 [2560/9886 (26%)]	Loss: 0.449835
# Train Epoch: 16 [3840/9886 (38%)]	Loss: 0.614554
# Train Epoch: 16 [5120/9886 (51%)]	Loss: 0.529927
# Train Epoch: 16 [6400/9886 (64%)]	Loss: 0.434270
# Train Epoch: 16 [7680/9886 (77%)]	Loss: 0.505322
# Train Epoch: 16 [8960/9886 (90%)]	Loss: 0.473146
# Total running time: 101.76234650611877
#
# Test set: Avg. loss: 0.0067, Accuracy: 418/521 (80%)
#
# Training Resnet18
# Train Epoch: 17 [0/9886 (0%)]	Loss: 0.545618
# Train Epoch: 17 [1280/9886 (13%)]	Loss: 0.419651
# Train Epoch: 17 [2560/9886 (26%)]	Loss: 0.456666
# Train Epoch: 17 [3840/9886 (38%)]	Loss: 0.442970
# Train Epoch: 17 [5120/9886 (51%)]	Loss: 0.377018
# Train Epoch: 17 [6400/9886 (64%)]	Loss: 0.440203
# Train Epoch: 17 [7680/9886 (77%)]	Loss: 0.361301
# Train Epoch: 17 [8960/9886 (90%)]	Loss: 0.371157
# Total running time: 102.34370493888855
#
# Test set: Avg. loss: 0.0064, Accuracy: 426/521 (82%)
#
# Training Resnet18
# Train Epoch: 18 [0/9886 (0%)]	Loss: 0.399365
# Train Epoch: 18 [1280/9886 (13%)]	Loss: 0.368881
# Train Epoch: 18 [2560/9886 (26%)]	Loss: 0.443861
# Train Epoch: 18 [3840/9886 (38%)]	Loss: 0.492406
# Train Epoch: 18 [5120/9886 (51%)]	Loss: 0.443402
# Train Epoch: 18 [6400/9886 (64%)]	Loss: 0.446949
# Train Epoch: 18 [7680/9886 (77%)]	Loss: 0.386860
# Train Epoch: 18 [8960/9886 (90%)]	Loss: 0.462765
# Total running time: 102.28876662254333
#
# Test set: Avg. loss: 0.0061, Accuracy: 430/521 (83%)
#
# Training Resnet18
# Train Epoch: 19 [0/9886 (0%)]	Loss: 0.413141
# Train Epoch: 19 [1280/9886 (13%)]	Loss: 0.411971
# Train Epoch: 19 [2560/9886 (26%)]	Loss: 0.393439
# Train Epoch: 19 [3840/9886 (38%)]	Loss: 0.334850
# Train Epoch: 19 [5120/9886 (51%)]	Loss: 0.375731
# Train Epoch: 19 [6400/9886 (64%)]	Loss: 0.458636
# Train Epoch: 19 [7680/9886 (77%)]	Loss: 0.462988
# Train Epoch: 19 [8960/9886 (90%)]	Loss: 0.355698
# Total running time: 101.28511619567871
#
# Test set: Avg. loss: 0.0059, Accuracy: 431/521 (83%)
#
# Training Resnet18
# Train Epoch: 20 [0/9886 (0%)]	Loss: 0.325106
# Train Epoch: 20 [1280/9886 (13%)]	Loss: 0.351163
# Train Epoch: 20 [2560/9886 (26%)]	Loss: 0.419199
# Train Epoch: 20 [3840/9886 (38%)]	Loss: 0.323172
# Train Epoch: 20 [5120/9886 (51%)]	Loss: 0.442476
# Train Epoch: 20 [6400/9886 (64%)]	Loss: 0.408024
# Train Epoch: 20 [7680/9886 (77%)]	Loss: 0.341921
# Train Epoch: 20 [8960/9886 (90%)]	Loss: 0.387660
# Total running time: 100.96815061569214
#
# Test set: Avg. loss: 0.0057, Accuracy: 433/521 (83%)
#
# Training Resnet18
# Train Epoch: 21 [0/9886 (0%)]	Loss: 0.443437
# Train Epoch: 21 [1280/9886 (13%)]	Loss: 0.304292
# Train Epoch: 21 [2560/9886 (26%)]	Loss: 0.394277
# Train Epoch: 21 [3840/9886 (38%)]	Loss: 0.311965
# Train Epoch: 21 [5120/9886 (51%)]	Loss: 0.302552
# Train Epoch: 21 [6400/9886 (64%)]	Loss: 0.381525
# Train Epoch: 21 [7680/9886 (77%)]	Loss: 0.389856
# Train Epoch: 21 [8960/9886 (90%)]	Loss: 0.364933
# Total running time: 101.1741955280304
#
# Test set: Avg. loss: 0.0055, Accuracy: 440/521 (84%)
#
# Training Resnet18
# Train Epoch: 22 [0/9886 (0%)]	Loss: 0.375251
# Train Epoch: 22 [1280/9886 (13%)]	Loss: 0.337319
# Train Epoch: 22 [2560/9886 (26%)]	Loss: 0.370213
# Train Epoch: 22 [3840/9886 (38%)]	Loss: 0.335559
# Train Epoch: 22 [5120/9886 (51%)]	Loss: 0.298063
# Train Epoch: 22 [6400/9886 (64%)]	Loss: 0.340590
# Train Epoch: 22 [7680/9886 (77%)]	Loss: 0.308289
# Train Epoch: 22 [8960/9886 (90%)]	Loss: 0.374290
# Total running time: 101.69905304908752
#
# Test set: Avg. loss: 0.0053, Accuracy: 440/521 (84%)
#
# Training Resnet18
# Train Epoch: 23 [0/9886 (0%)]	Loss: 0.303523
# Train Epoch: 23 [1280/9886 (13%)]	Loss: 0.223790
# Train Epoch: 23 [2560/9886 (26%)]	Loss: 0.259014
# Train Epoch: 23 [3840/9886 (38%)]	Loss: 0.287086
# Train Epoch: 23 [5120/9886 (51%)]	Loss: 0.287638
# Train Epoch: 23 [6400/9886 (64%)]	Loss: 0.288155
# Train Epoch: 23 [7680/9886 (77%)]	Loss: 0.250313
# Train Epoch: 23 [8960/9886 (90%)]	Loss: 0.329331
# Total running time: 100.05506801605225
#
# Test set: Avg. loss: 0.0051, Accuracy: 445/521 (85%)
#
# Training Resnet18
# Train Epoch: 24 [0/9886 (0%)]	Loss: 0.285866
# Train Epoch: 24 [1280/9886 (13%)]	Loss: 0.202437
# Train Epoch: 24 [2560/9886 (26%)]	Loss: 0.244901
# Train Epoch: 24 [3840/9886 (38%)]	Loss: 0.246901
# Train Epoch: 24 [5120/9886 (51%)]	Loss: 0.334785
# Train Epoch: 24 [6400/9886 (64%)]	Loss: 0.315332
# Train Epoch: 24 [7680/9886 (77%)]	Loss: 0.361275
# Train Epoch: 24 [8960/9886 (90%)]	Loss: 0.282153
# Total running time: 101.58078670501709
#
# Test set: Avg. loss: 0.0050, Accuracy: 448/521 (86%)
#
# Training Resnet18
# Train Epoch: 25 [0/9886 (0%)]	Loss: 0.275881
# Train Epoch: 25 [1280/9886 (13%)]	Loss: 0.260133
# Train Epoch: 25 [2560/9886 (26%)]	Loss: 0.225833
# Train Epoch: 25 [3840/9886 (38%)]	Loss: 0.265929
# Train Epoch: 25 [5120/9886 (51%)]	Loss: 0.217515
# Train Epoch: 25 [6400/9886 (64%)]	Loss: 0.186603
# Train Epoch: 25 [7680/9886 (77%)]	Loss: 0.267406
# Train Epoch: 25 [8960/9886 (90%)]	Loss: 0.242645
# Total running time: 100.88758945465088
#
# Test set: Avg. loss: 0.0048, Accuracy: 449/521 (86%)
#
# Training Resnet18
# Train Epoch: 26 [0/9886 (0%)]	Loss: 0.211054
# Train Epoch: 26 [1280/9886 (13%)]	Loss: 0.255763
# Train Epoch: 26 [2560/9886 (26%)]	Loss: 0.242712
# Train Epoch: 26 [3840/9886 (38%)]	Loss: 0.237697
# Train Epoch: 26 [5120/9886 (51%)]	Loss: 0.218129
# Train Epoch: 26 [6400/9886 (64%)]	Loss: 0.256511
# Train Epoch: 26 [7680/9886 (77%)]	Loss: 0.217672
# Train Epoch: 26 [8960/9886 (90%)]	Loss: 0.245421
# Total running time: 99.89119958877563
#
# Test set: Avg. loss: 0.0046, Accuracy: 452/521 (87%)
#
# Training Resnet18
# Train Epoch: 27 [0/9886 (0%)]	Loss: 0.186345
# Train Epoch: 27 [1280/9886 (13%)]	Loss: 0.185023
# Train Epoch: 27 [2560/9886 (26%)]	Loss: 0.236101
# Train Epoch: 27 [3840/9886 (38%)]	Loss: 0.205162
# Train Epoch: 27 [5120/9886 (51%)]	Loss: 0.183687
# Train Epoch: 27 [6400/9886 (64%)]	Loss: 0.203076
# Train Epoch: 27 [7680/9886 (77%)]	Loss: 0.171195
# Train Epoch: 27 [8960/9886 (90%)]	Loss: 0.167952
# Total running time: 101.94453740119934
#
# Test set: Avg. loss: 0.0045, Accuracy: 455/521 (87%)
#
# Training Resnet18
# Train Epoch: 28 [0/9886 (0%)]	Loss: 0.261945
# Train Epoch: 28 [1280/9886 (13%)]	Loss: 0.242116
# Train Epoch: 28 [2560/9886 (26%)]	Loss: 0.232568
# Train Epoch: 28 [3840/9886 (38%)]	Loss: 0.230968
# Train Epoch: 28 [5120/9886 (51%)]	Loss: 0.153007
# Train Epoch: 28 [6400/9886 (64%)]	Loss: 0.137056
# Train Epoch: 28 [7680/9886 (77%)]	Loss: 0.168464
# Train Epoch: 28 [8960/9886 (90%)]	Loss: 0.247073
# Total running time: 100.86403942108154
#
# Test set: Avg. loss: 0.0044, Accuracy: 456/521 (88%)
#
# Training Resnet18
# Train Epoch: 29 [0/9886 (0%)]	Loss: 0.248386
# Train Epoch: 29 [1280/9886 (13%)]	Loss: 0.202135
# Train Epoch: 29 [2560/9886 (26%)]	Loss: 0.253282
# Train Epoch: 29 [3840/9886 (38%)]	Loss: 0.150029
# Train Epoch: 29 [5120/9886 (51%)]	Loss: 0.189553
# Train Epoch: 29 [6400/9886 (64%)]	Loss: 0.188486
# Train Epoch: 29 [7680/9886 (77%)]	Loss: 0.211676
# Train Epoch: 29 [8960/9886 (90%)]	Loss: 0.197819
# Total running time: 101.20788979530334
#
# Test set: Avg. loss: 0.0043, Accuracy: 457/521 (88%)
#
# Training Resnet18
# Train Epoch: 30 [0/9886 (0%)]	Loss: 0.175237
# Train Epoch: 30 [1280/9886 (13%)]	Loss: 0.176161
# Train Epoch: 30 [2560/9886 (26%)]	Loss: 0.202770
# Train Epoch: 30 [3840/9886 (38%)]	Loss: 0.180529
# Train Epoch: 30 [5120/9886 (51%)]	Loss: 0.168886
# Train Epoch: 30 [6400/9886 (64%)]	Loss: 0.202828
# Train Epoch: 30 [7680/9886 (77%)]	Loss: 0.189020
# Train Epoch: 30 [8960/9886 (90%)]	Loss: 0.206206
# Total running time: 101.65503001213074
#
# Test set: Avg. loss: 0.0041, Accuracy: 461/521 (88%)
#
# Training Resnet18
# Train Epoch: 31 [0/9886 (0%)]	Loss: 0.204570
# Train Epoch: 31 [1280/9886 (13%)]	Loss: 0.130186
# Train Epoch: 31 [2560/9886 (26%)]	Loss: 0.159790
# Train Epoch: 31 [3840/9886 (38%)]	Loss: 0.138685
# Train Epoch: 31 [5120/9886 (51%)]	Loss: 0.171292
# Train Epoch: 31 [6400/9886 (64%)]	Loss: 0.135652
# Train Epoch: 31 [7680/9886 (77%)]	Loss: 0.145261
# Train Epoch: 31 [8960/9886 (90%)]	Loss: 0.169791
# Total running time: 100.94466614723206
#
# Test set: Avg. loss: 0.0041, Accuracy: 462/521 (89%)
#
# Training Resnet18
# Train Epoch: 32 [0/9886 (0%)]	Loss: 0.154881
# Train Epoch: 32 [1280/9886 (13%)]	Loss: 0.196676
# Train Epoch: 32 [2560/9886 (26%)]	Loss: 0.124326
# Train Epoch: 32 [3840/9886 (38%)]	Loss: 0.166186
# Train Epoch: 32 [5120/9886 (51%)]	Loss: 0.143507
# Train Epoch: 32 [6400/9886 (64%)]	Loss: 0.146574
# Train Epoch: 32 [7680/9886 (77%)]	Loss: 0.121338
# Train Epoch: 32 [8960/9886 (90%)]	Loss: 0.185603
# Total running time: 100.61050844192505
#
# Test set: Avg. loss: 0.0040, Accuracy: 464/521 (89%)
#
# Training Resnet18
# Train Epoch: 33 [0/9886 (0%)]	Loss: 0.169914
# Train Epoch: 33 [1280/9886 (13%)]	Loss: 0.128030
# Train Epoch: 33 [2560/9886 (26%)]	Loss: 0.120045
# Train Epoch: 33 [3840/9886 (38%)]	Loss: 0.148347
# Train Epoch: 33 [5120/9886 (51%)]	Loss: 0.139522
# Train Epoch: 33 [6400/9886 (64%)]	Loss: 0.151042
# Train Epoch: 33 [7680/9886 (77%)]	Loss: 0.110954
# Train Epoch: 33 [8960/9886 (90%)]	Loss: 0.138269
# Total running time: 101.1949028968811
#
# Test set: Avg. loss: 0.0039, Accuracy: 470/521 (90%)
#
# Training Resnet18
# Train Epoch: 34 [0/9886 (0%)]	Loss: 0.157409
# Train Epoch: 34 [1280/9886 (13%)]	Loss: 0.085802
# Train Epoch: 34 [2560/9886 (26%)]	Loss: 0.160167
# Train Epoch: 34 [3840/9886 (38%)]	Loss: 0.106619
# Train Epoch: 34 [5120/9886 (51%)]	Loss: 0.146003
# Train Epoch: 34 [6400/9886 (64%)]	Loss: 0.131016
# Train Epoch: 34 [7680/9886 (77%)]	Loss: 0.195419
# Train Epoch: 34 [8960/9886 (90%)]	Loss: 0.118991
# Total running time: 101.00292229652405
#
# Test set: Avg. loss: 0.0038, Accuracy: 467/521 (90%)
#
# Training Resnet18
# Train Epoch: 35 [0/9886 (0%)]	Loss: 0.176930
# Train Epoch: 35 [1280/9886 (13%)]	Loss: 0.128093
# Train Epoch: 35 [2560/9886 (26%)]	Loss: 0.143800
# Train Epoch: 35 [3840/9886 (38%)]	Loss: 0.163311
# Train Epoch: 35 [5120/9886 (51%)]	Loss: 0.103926
# Train Epoch: 35 [6400/9886 (64%)]	Loss: 0.158531
# Train Epoch: 35 [7680/9886 (77%)]	Loss: 0.100554
# Train Epoch: 35 [8960/9886 (90%)]	Loss: 0.170740
# Total running time: 100.6616485118866
#
# Test set: Avg. loss: 0.0037, Accuracy: 465/521 (89%)
#
# Training Resnet18
# Train Epoch: 36 [0/9886 (0%)]	Loss: 0.102607
# Train Epoch: 36 [1280/9886 (13%)]	Loss: 0.109220
# Train Epoch: 36 [2560/9886 (26%)]	Loss: 0.118445
# Train Epoch: 36 [3840/9886 (38%)]	Loss: 0.110090
# Train Epoch: 36 [5120/9886 (51%)]	Loss: 0.114710
# Train Epoch: 36 [6400/9886 (64%)]	Loss: 0.122825
# Train Epoch: 36 [7680/9886 (77%)]	Loss: 0.096518
# Train Epoch: 36 [8960/9886 (90%)]	Loss: 0.145427
# Total running time: 99.21879816055298
#
# Test set: Avg. loss: 0.0036, Accuracy: 466/521 (89%)
#
# Training Resnet18
# Train Epoch: 37 [0/9886 (0%)]	Loss: 0.115742
# Train Epoch: 37 [1280/9886 (13%)]	Loss: 0.094369
# Train Epoch: 37 [2560/9886 (26%)]	Loss: 0.138532
# Train Epoch: 37 [3840/9886 (38%)]	Loss: 0.115842
# Train Epoch: 37 [5120/9886 (51%)]	Loss: 0.099361
# Train Epoch: 37 [6400/9886 (64%)]	Loss: 0.154096
# Train Epoch: 37 [7680/9886 (77%)]	Loss: 0.091646
# Train Epoch: 37 [8960/9886 (90%)]	Loss: 0.098846
# Total running time: 101.51407861709595
#
# Test set: Avg. loss: 0.0035, Accuracy: 470/521 (90%)
#
# Training Resnet18
# Train Epoch: 38 [0/9886 (0%)]	Loss: 0.116072
# Train Epoch: 38 [1280/9886 (13%)]	Loss: 0.126933
# Train Epoch: 38 [2560/9886 (26%)]	Loss: 0.123884
# Train Epoch: 38 [3840/9886 (38%)]	Loss: 0.131510
# Train Epoch: 38 [5120/9886 (51%)]	Loss: 0.080834
# Train Epoch: 38 [6400/9886 (64%)]	Loss: 0.084139
# Train Epoch: 38 [7680/9886 (77%)]	Loss: 0.092758
# Train Epoch: 38 [8960/9886 (90%)]	Loss: 0.103245
# Total running time: 100.98069047927856
#
# ...
# Train Epoch: 49 [5120/9886 (51%)]	Loss: 0.105101
# Train Epoch: 49 [7680/9886 (77%)]	Loss: 0.082687
# Total running time: 128.5554814338684
#
# Test set: Avg. loss: 0.0023, Accuracy: 451/521 (87%)
#
# Training Resnet34, batch size 256
# Train Epoch: 50 [0/9886 (0%)]	Loss: 0.097164
# Train Epoch: 50 [2560/9886 (26%)]	Loss: 0.082862
# Train Epoch: 50 [5120/9886 (51%)]	Loss: 0.093359
# Train Epoch: 50 [7680/9886 (77%)]	Loss: 0.077414
# Total running time: 129.52930092811584
#
# Test set: Avg. loss: 0.0022, Accuracy: 448/521 (86%)
#
# accuracy_resnet34_batch_256 [26.29558563232422, 37.61996078491211, 42.418426513671875, 49.71208953857422, 55.2783088684082, 58.349327087402344, 61.2284049987793, 62.763912200927734, 65.45105743408203, 66.6026840209961, 68.13819122314453, 68.90594482421875, 70.24951934814453, 70.63339233398438, 72.16890716552734, 74.28022766113281, 75.23992156982422, 75.62379455566406, 76.77542877197266, 77.15930938720703, 77.92706298828125, 78.69481658935547, 79.46257019042969, 79.46257019042969, 80.99807739257812, 81.19001770019531, 81.19001770019531, 81.57389068603516, 82.14971160888672, 81.76583099365234, 81.95777130126953, 82.3416519165039, 82.91746520996094, 83.49327850341797, 83.68521881103516, 83.87715911865234, 84.64491271972656, 84.83685302734375, 84.64491271972656, 85.0287857055664, 85.2207260131836, 85.0287857055664, 85.60460662841797, 85.60460662841797, 85.98847961425781, 85.79653930664062, 86.180419921875, 86.37236022949219, 86.56430053710938, 85.98847961425781]
#
# Training Resnet34, batch size 384
# Train Epoch: 1 [0/9886 (0%)]	Loss: 2.402382
# Train Epoch: 1 [3840/9886 (38%)]	Loss: 2.284806
# Train Epoch: 1 [7680/9886 (77%)]	Loss: 2.146132
# Total running time: 130.50194907188416
#
# Test set: Avg. loss: 0.0081, Accuracy: 121/521 (23%)
#
# Training Resnet34, batch size 384
# Train Epoch: 2 [0/9886 (0%)]	Loss: 2.134229
# Train Epoch: 2 [3840/9886 (38%)]	Loss: 2.062139
# Train Epoch: 2 [7680/9886 (77%)]	Loss: 1.975253
# Total running time: 131.4021499156952
#
# Test set: Avg. loss: 0.0076, Accuracy: 166/521 (32%)
#
# Training Resnet34, batch size 384
# Train Epoch: 3 [0/9886 (0%)]	Loss: 2.011652
# Train Epoch: 3 [3840/9886 (38%)]	Loss: 1.949291
# Train Epoch: 3 [7680/9886 (77%)]	Loss: 1.932967
# Total running time: 129.78850269317627
#
# Test set: Avg. loss: 0.0072, Accuracy: 201/521 (39%)
#
# Training Resnet34, batch size 384
# Train Epoch: 4 [0/9886 (0%)]	Loss: 1.852644
# Train Epoch: 4 [3840/9886 (38%)]	Loss: 1.778792
# Train Epoch: 4 [7680/9886 (77%)]	Loss: 1.801886
# Total running time: 131.000629901886
#
# Test set: Avg. loss: 0.0069, Accuracy: 222/521 (43%)
#
# Training Resnet34, batch size 384
# Train Epoch: 5 [0/9886 (0%)]	Loss: 1.813023
# Train Epoch: 5 [3840/9886 (38%)]	Loss: 1.799540
# Train Epoch: 5 [7680/9886 (77%)]	Loss: 1.717255
# Total running time: 130.32580089569092
#
# Test set: Avg. loss: 0.0066, Accuracy: 236/521 (45%)
#
# Training Resnet34, batch size 384
# Train Epoch: 6 [0/9886 (0%)]	Loss: 1.664556
# Train Epoch: 6 [3840/9886 (38%)]	Loss: 1.753335
# Train Epoch: 6 [7680/9886 (77%)]	Loss: 1.581439
# Total running time: 129.1137969493866
#
# Test set: Avg. loss: 0.0063, Accuracy: 253/521 (49%)
#
# Training Resnet34, batch size 384
# Train Epoch: 7 [0/9886 (0%)]	Loss: 1.650323
# Train Epoch: 7 [3840/9886 (38%)]	Loss: 1.564446
# Train Epoch: 7 [7680/9886 (77%)]	Loss: 1.615668
# Total running time: 131.8454806804657
#
# Test set: Avg. loss: 0.0060, Accuracy: 270/521 (52%)
#
# Training Resnet34, batch size 384
# Train Epoch: 8 [0/9886 (0%)]	Loss: 1.550854
# Train Epoch: 8 [3840/9886 (38%)]	Loss: 1.533285
# Train Epoch: 8 [7680/9886 (77%)]	Loss: 1.405470
# Total running time: 130.9405529499054
#
# Test set: Avg. loss: 0.0058, Accuracy: 283/521 (54%)
#
# Training Resnet34, batch size 384
# Train Epoch: 9 [0/9886 (0%)]	Loss: 1.455397
# Train Epoch: 9 [3840/9886 (38%)]	Loss: 1.366420
# Train Epoch: 9 [7680/9886 (77%)]	Loss: 1.326763
# Total running time: 131.13052988052368
#
# Test set: Avg. loss: 0.0055, Accuracy: 297/521 (57%)
#
# Training Resnet34, batch size 384
# Train Epoch: 10 [0/9886 (0%)]	Loss: 1.425467
# Train Epoch: 10 [3840/9886 (38%)]	Loss: 1.325897
# Train Epoch: 10 [7680/9886 (77%)]	Loss: 1.243801
# Total running time: 131.08919405937195
#
# Test set: Avg. loss: 0.0053, Accuracy: 307/521 (59%)
#
# Training Resnet34, batch size 384
# Train Epoch: 11 [0/9886 (0%)]	Loss: 1.263096
# Train Epoch: 11 [3840/9886 (38%)]	Loss: 1.335758
# Train Epoch: 11 [7680/9886 (77%)]	Loss: 1.252523
# Total running time: 130.13014841079712
#
# Test set: Avg. loss: 0.0051, Accuracy: 324/521 (62%)
#
# Training Resnet34, batch size 384
# Train Epoch: 12 [0/9886 (0%)]	Loss: 1.207350
# Train Epoch: 12 [3840/9886 (38%)]	Loss: 1.200469
# Train Epoch: 12 [7680/9886 (77%)]	Loss: 1.153189
# Total running time: 131.22042870521545
#
# Test set: Avg. loss: 0.0049, Accuracy: 331/521 (64%)
#
# Training Resnet34, batch size 384
# Train Epoch: 13 [0/9886 (0%)]	Loss: 1.135161
# Train Epoch: 13 [3840/9886 (38%)]	Loss: 1.145062
# Train Epoch: 13 [7680/9886 (77%)]	Loss: 1.181988
# Total running time: 130.045973777771
#
# Test set: Avg. loss: 0.0047, Accuracy: 335/521 (64%)
#
# Training Resnet34, batch size 384
# Train Epoch: 14 [0/9886 (0%)]	Loss: 1.140958
# Train Epoch: 14 [3840/9886 (38%)]	Loss: 1.138058
# Train Epoch: 14 [7680/9886 (77%)]	Loss: 1.121473
# Total running time: 130.91986441612244
#
# Test set: Avg. loss: 0.0045, Accuracy: 341/521 (65%)
#
# Training Resnet34, batch size 384
# Train Epoch: 15 [0/9886 (0%)]	Loss: 1.035408
# Train Epoch: 15 [3840/9886 (38%)]	Loss: 1.044165
# Train Epoch: 15 [7680/9886 (77%)]	Loss: 0.979412
# Total running time: 130.65794467926025
#
# Test set: Avg. loss: 0.0043, Accuracy: 348/521 (67%)
#
# Training Resnet34, batch size 384
# Train Epoch: 16 [0/9886 (0%)]	Loss: 1.024390
# Train Epoch: 16 [3840/9886 (38%)]	Loss: 0.970202
# Train Epoch: 16 [7680/9886 (77%)]	Loss: 1.042046
# Total running time: 130.84490418434143
#
# Test set: Avg. loss: 0.0042, Accuracy: 360/521 (69%)
#
# Training Resnet34, batch size 384
# Train Epoch: 17 [0/9886 (0%)]	Loss: 0.979591
# Train Epoch: 17 [3840/9886 (38%)]	Loss: 0.921994
# Train Epoch: 17 [7680/9886 (77%)]	Loss: 0.944440
# Total running time: 130.5966658592224
#
# Test set: Avg. loss: 0.0040, Accuracy: 366/521 (70%)
#
# Training Resnet34, batch size 384
# Train Epoch: 18 [0/9886 (0%)]	Loss: 0.910817
# Train Epoch: 18 [3840/9886 (38%)]	Loss: 0.846667
# Train Epoch: 18 [7680/9886 (77%)]	Loss: 0.852632
# Total running time: 131.65752243995667
#
# Test set: Avg. loss: 0.0039, Accuracy: 371/521 (71%)
#
# Training Resnet34, batch size 384
# Train Epoch: 19 [0/9886 (0%)]	Loss: 0.897135
# Train Epoch: 19 [3840/9886 (38%)]	Loss: 0.861592
# Train Epoch: 19 [7680/9886 (77%)]	Loss: 0.908691
# Total running time: 130.5155246257782
#
# Test set: Avg. loss: 0.0038, Accuracy: 376/521 (72%)
#
# Training Resnet34, batch size 384
# Train Epoch: 20 [0/9886 (0%)]	Loss: 0.863101
# Train Epoch: 20 [3840/9886 (38%)]	Loss: 0.802198
# Train Epoch: 20 [7680/9886 (77%)]	Loss: 0.824582
# Total running time: 131.20029711723328
#
# Test set: Avg. loss: 0.0037, Accuracy: 377/521 (72%)
#
# Training Resnet34, batch size 384
# Train Epoch: 21 [0/9886 (0%)]	Loss: 0.819165
# Train Epoch: 21 [3840/9886 (38%)]	Loss: 0.798769
# Train Epoch: 21 [7680/9886 (77%)]	Loss: 0.741706
# Total running time: 129.44361662864685
#
# Test set: Avg. loss: 0.0036, Accuracy: 384/521 (74%)
#
# Training Resnet34, batch size 384
# Train Epoch: 22 [0/9886 (0%)]	Loss: 0.781969
# Train Epoch: 22 [3840/9886 (38%)]	Loss: 0.709869
# Train Epoch: 22 [7680/9886 (77%)]	Loss: 0.742667
# Total running time: 131.86515855789185
#
# Test set: Avg. loss: 0.0035, Accuracy: 388/521 (74%)
#
# Training Resnet34, batch size 384
# Train Epoch: 23 [0/9886 (0%)]	Loss: 0.734803
# Train Epoch: 23 [3840/9886 (38%)]	Loss: 0.766738
# Train Epoch: 23 [7680/9886 (77%)]	Loss: 0.646698
# Total running time: 130.45308208465576
#
# Test set: Avg. loss: 0.0034, Accuracy: 391/521 (75%)
#
# Training Resnet34, batch size 384
# Train Epoch: 24 [0/9886 (0%)]	Loss: 0.734174
# Train Epoch: 24 [3840/9886 (38%)]	Loss: 0.666007
# Train Epoch: 24 [7680/9886 (77%)]	Loss: 0.689553
# Total running time: 130.86015796661377
#
# Test set: Avg. loss: 0.0033, Accuracy: 392/521 (75%)
#
# Training Resnet34, batch size 384
# Train Epoch: 25 [0/9886 (0%)]	Loss: 0.623554
# Train Epoch: 25 [3840/9886 (38%)]	Loss: 0.640186
# Train Epoch: 25 [7680/9886 (77%)]	Loss: 0.681308
# Total running time: 131.89293146133423
#
# Test set: Avg. loss: 0.0032, Accuracy: 395/521 (76%)
#
# Training Resnet34, batch size 384
# Train Epoch: 26 [0/9886 (0%)]	Loss: 0.603594
# Train Epoch: 26 [3840/9886 (38%)]	Loss: 0.603542
# Train Epoch: 26 [7680/9886 (77%)]	Loss: 0.561946
# Total running time: 130.8967535495758
#
# Test set: Avg. loss: 0.0031, Accuracy: 400/521 (77%)
#
# Training Resnet34, batch size 384
# Train Epoch: 27 [0/9886 (0%)]	Loss: 0.602449
# Train Epoch: 27 [3840/9886 (38%)]	Loss: 0.591433
# Train Epoch: 27 [7680/9886 (77%)]	Loss: 0.567607
# Total running time: 131.58881425857544
#
# Test set: Avg. loss: 0.0030, Accuracy: 404/521 (78%)
#
# Training Resnet34, batch size 384
# Train Epoch: 28 [0/9886 (0%)]	Loss: 0.578276
# Train Epoch: 28 [3840/9886 (38%)]	Loss: 0.492571
# Train Epoch: 28 [7680/9886 (77%)]	Loss: 0.642729
# Total running time: 131.06899619102478
#
# Test set: Avg. loss: 0.0030, Accuracy: 405/521 (78%)
#
# Training Resnet34, batch size 384
# Train Epoch: 29 [0/9886 (0%)]	Loss: 0.509670
# Train Epoch: 29 [3840/9886 (38%)]	Loss: 0.556751
# Train Epoch: 29 [7680/9886 (77%)]	Loss: 0.553201
# Total running time: 129.71091318130493
#
# Test set: Avg. loss: 0.0029, Accuracy: 409/521 (79%)
#
# Training Resnet34, batch size 384
# Train Epoch: 30 [0/9886 (0%)]	Loss: 0.535513
# Train Epoch: 30 [3840/9886 (38%)]	Loss: 0.497180
# Train Epoch: 30 [7680/9886 (77%)]	Loss: 0.514231
# Total running time: 130.95020270347595
#
# Test set: Avg. loss: 0.0028, Accuracy: 412/521 (79%)
#
# Training Resnet34, batch size 384
# Train Epoch: 31 [0/9886 (0%)]	Loss: 0.532224
# Train Epoch: 31 [3840/9886 (38%)]	Loss: 0.485878
# Train Epoch: 31 [7680/9886 (77%)]	Loss: 0.487144
# Total running time: 131.1723837852478
#
# Test set: Avg. loss: 0.0028, Accuracy: 412/521 (79%)
#
# Training Resnet34, batch size 384
# Train Epoch: 32 [0/9886 (0%)]	Loss: 0.491871
# Train Epoch: 32 [3840/9886 (38%)]	Loss: 0.425579
# Train Epoch: 32 [7680/9886 (77%)]	Loss: 0.482140
# Total running time: 131.36540722846985
#
# Test set: Avg. loss: 0.0027, Accuracy: 415/521 (80%)
#
# Training Resnet34, batch size 384
# Train Epoch: 33 [0/9886 (0%)]	Loss: 0.446046
# Train Epoch: 33 [3840/9886 (38%)]	Loss: 0.456736
# Train Epoch: 33 [7680/9886 (77%)]	Loss: 0.464702
# Total running time: 130.27426028251648
#
# Test set: Avg. loss: 0.0027, Accuracy: 416/521 (80%)
#
# Training Resnet34, batch size 384
# Train Epoch: 34 [0/9886 (0%)]	Loss: 0.455489
# Train Epoch: 34 [3840/9886 (38%)]	Loss: 0.435254
# Train Epoch: 34 [7680/9886 (77%)]	Loss: 0.463275
# Total running time: 130.31224942207336
#
# Test set: Avg. loss: 0.0026, Accuracy: 419/521 (80%)
#
# Training Resnet34, batch size 384
# Train Epoch: 35 [0/9886 (0%)]	Loss: 0.406831
# Train Epoch: 35 [3840/9886 (38%)]	Loss: 0.417939
# Train Epoch: 35 [7680/9886 (77%)]	Loss: 0.438111
# Total running time: 131.95198464393616
#
# Test set: Avg. loss: 0.0025, Accuracy: 423/521 (81%)
#
# Training Resnet34, batch size 384
# Train Epoch: 36 [0/9886 (0%)]	Loss: 0.392962
# Train Epoch: 36 [3840/9886 (38%)]	Loss: 0.403434
# Train Epoch: 36 [7680/9886 (77%)]	Loss: 0.408497
# Total running time: 132.45015716552734
#
# Test set: Avg. loss: 0.0025, Accuracy: 423/521 (81%)
#
# Training Resnet34, batch size 384
# Train Epoch: 37 [0/9886 (0%)]	Loss: 0.433539
# Train Epoch: 37 [3840/9886 (38%)]	Loss: 0.351225
# Train Epoch: 37 [7680/9886 (77%)]	Loss: 0.419140
# Total running time: 130.61629676818848
#
# Test set: Avg. loss: 0.0025, Accuracy: 424/521 (81%)
#
# Training Resnet34, batch size 384
# Train Epoch: 38 [0/9886 (0%)]	Loss: 0.360212
# Train Epoch: 38 [3840/9886 (38%)]	Loss: 0.337442
# Train Epoch: 38 [7680/9886 (77%)]	Loss: 0.360063
# Total running time: 131.05923199653625
#
# Test set: Avg. loss: 0.0024, Accuracy: 429/521 (82%)
#
# Training Resnet34, batch size 384
# Train Epoch: 39 [0/9886 (0%)]	Loss: 0.332755
# Train Epoch: 39 [3840/9886 (38%)]	Loss: 0.411295
# Train Epoch: 39 [7680/9886 (77%)]	Loss: 0.351451
# Total running time: 132.4826672077179
#
# Test set: Avg. loss: 0.0024, Accuracy: 426/521 (82%)
#
# Training Resnet34, batch size 384
# Train Epoch: 40 [0/9886 (0%)]	Loss: 0.303776
# Train Epoch: 40 [3840/9886 (38%)]	Loss: 0.330667
# Train Epoch: 40 [7680/9886 (77%)]	Loss: 0.371360
# Total running time: 131.73241090774536
#
# Test set: Avg. loss: 0.0023, Accuracy: 428/521 (82%)
#
# Training Resnet34, batch size 384
# Train Epoch: 41 [0/9886 (0%)]	Loss: 0.316598
# Train Epoch: 41 [3840/9886 (38%)]	Loss: 0.311379
# Train Epoch: 41 [7680/9886 (77%)]	Loss: 0.270775
# Total running time: 131.80313658714294
#
# Test set: Avg. loss: 0.0023, Accuracy: 430/521 (83%)
#
# Training Resnet34, batch size 384
# Train Epoch: 42 [0/9886 (0%)]	Loss: 0.321545
# Train Epoch: 42 [3840/9886 (38%)]	Loss: 0.329656
# Train Epoch: 42 [7680/9886 (77%)]	Loss: 0.291969
# Total running time: 131.7475564479828
#
# Test set: Avg. loss: 0.0022, Accuracy: 430/521 (83%)
#
# Training Resnet34, batch size 384
# Train Epoch: 43 [0/9886 (0%)]	Loss: 0.285332
# Train Epoch: 43 [3840/9886 (38%)]	Loss: 0.317663
# Train Epoch: 43 [7680/9886 (77%)]	Loss: 0.287203
# Total running time: 129.4430434703827
#
# Test set: Avg. loss: 0.0022, Accuracy: 433/521 (83%)
#
# Training Resnet34, batch size 384
# Train Epoch: 44 [0/9886 (0%)]	Loss: 0.293306
# Train Epoch: 44 [3840/9886 (38%)]	Loss: 0.335454
# Train Epoch: 44 [7680/9886 (77%)]	Loss: 0.299047
# Total running time: 130.12414288520813
#
# Test set: Avg. loss: 0.0022, Accuracy: 432/521 (83%)
#
# Training Resnet34, batch size 384
# Train Epoch: 45 [0/9886 (0%)]	Loss: 0.330269
# Train Epoch: 45 [3840/9886 (38%)]	Loss: 0.251939
# Train Epoch: 45 [7680/9886 (77%)]	Loss: 0.235608
# Total running time: 128.89271879196167
#
# Test set: Avg. loss: 0.0021, Accuracy: 434/521 (83%)
#
# Training Resnet34, batch size 384
# Train Epoch: 46 [0/9886 (0%)]	Loss: 0.274199
# Train Epoch: 46 [3840/9886 (38%)]	Loss: 0.296377
# Train Epoch: 46 [7680/9886 (77%)]	Loss: 0.262281
# Total running time: 129.21362233161926
#
# Test set: Avg. loss: 0.0021, Accuracy: 436/521 (84%)
#
# Training Resnet34, batch size 384
# Train Epoch: 47 [0/9886 (0%)]	Loss: 0.243302
# Train Epoch: 47 [3840/9886 (38%)]	Loss: 0.230536
# Train Epoch: 47 [7680/9886 (77%)]	Loss: 0.230946
# Total running time: 128.84103870391846
#
# Test set: Avg. loss: 0.0021, Accuracy: 435/521 (83%)
#
# Training Resnet34, batch size 384
# Train Epoch: 48 [0/9886 (0%)]	Loss: 0.246639
# Train Epoch: 48 [3840/9886 (38%)]	Loss: 0.246536
# Train Epoch: 48 [7680/9886 (77%)]	Loss: 0.231739
# Total running time: 131.03984808921814
#
# Test set: Avg. loss: 0.0021, Accuracy: 438/521 (84%)
#
# Training Resnet34, batch size 384
# Train Epoch: 49 [0/9886 (0%)]	Loss: 0.217661
# Train Epoch: 49 [3840/9886 (38%)]	Loss: 0.245687
# Train Epoch: 49 [7680/9886 (77%)]	Loss: 0.230049
# Total running time: 132.62118077278137
#
# Test set: Avg. loss: 0.0020, Accuracy: 437/521 (84%)
#
# Training Resnet34, batch size 384
# Train Epoch: 50 [0/9886 (0%)]	Loss: 0.235489
# Train Epoch: 50 [3840/9886 (38%)]	Loss: 0.238800
# Train Epoch: 50 [7680/9886 (77%)]	Loss: 0.232163
# Total running time: 129.96176481246948
#
# Test set: Avg. loss: 0.0020, Accuracy: 439/521 (84%)
#
# accuracy_resnet34_batch_384 [23.224567413330078, 31.86180305480957, 38.579654693603516, 42.6103630065918, 45.29750442504883, 48.56045913696289, 51.82341384887695, 54.3186149597168, 57.00575637817383, 58.92514419555664, 62.1880989074707, 63.53166961669922, 64.29942321777344, 65.45105743408203, 66.79462432861328, 69.09788513183594, 70.24951934814453, 71.20921325683594, 72.16890716552734, 72.36083984375, 73.70441436767578, 74.47216796875, 75.04798126220703, 75.23992156982422, 75.81573486328125, 76.77542877197266, 77.54318237304688, 77.73512268066406, 78.50287628173828, 79.07868957519531, 79.07868957519531, 79.65451049804688, 79.84644317626953, 80.4222640991211, 81.19001770019531, 81.19001770019531, 81.3819580078125, 82.3416519165039, 81.76583099365234, 82.14971160888672, 82.53358459472656, 82.53358459472656, 83.10940551757812, 82.91746520996094, 83.30133819580078, 83.68521881103516, 83.49327850341797, 84.069091796875, 83.87715911865234, 84.26103210449219]
# Total running time: 25462.738425970078
